# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# %%
first_cacao_df=pd.read_csv("flavors_of_cacao2.csv",encoding="utf-8")
first_cacao_df
# Out:
#      Company (Maker-if known) Specific Bean Origin or Bar Name   REF  \
# 0                    A. Morin                      Agua Grande  1876
# 1                    A. Morin                            Kpime  1676
# 2                    A. Morin                           Atsane  1676
# 3                    A. Morin                            Akata  1680
# 4                    A. Morin                           Quilla  1704
# ...                       ...                              ...   ...
# 1790                   Zotter                             Peru   647
# 1791                   Zotter                            Congo   749
# 1792                   Zotter                     Kerala State   749
# 1793                   Zotter                     Kerala State   781
# 1794                   Zotter               Brazil, Mitzi Blue   486
#
#       Review Date Cocoa Percent Company Location  Rating  Bean Type  \
# 0            2016           63%           France    3.75
# ...

# %%
first_cacao_df.columns
# Out:
# Index(['Company (Maker-if known)', 'Specific Bean Origin or Bar Name', 'REF',
#        'Review Date', 'Cocoa Percent', 'Company Location', 'Rating',
#        'Bean Type', 'Broad Bean Origin'],
#       dtype='object')

# %%
#drop bean column
no_bean_df=first_cacao_df.loc[:, ['Company (Maker-if known)', 'Specific Bean Origin or Bar Name', 'REF',
       'Review Date', 'Cocoa Percent', 'Company Location', 'Rating', 'Broad Bean Origin']]

no_bean_df
# Out:
#      Company (Maker-if known) Specific Bean Origin or Bar Name   REF  \
# 0                    A. Morin                      Agua Grande  1876
# 1                    A. Morin                            Kpime  1676
# 2                    A. Morin                           Atsane  1676
# 3                    A. Morin                            Akata  1680
# 4                    A. Morin                           Quilla  1704
# ...                       ...                              ...   ...
# 1790                   Zotter                             Peru   647
# 1791                   Zotter                            Congo   749
# 1792                   Zotter                     Kerala State   749
# 1793                   Zotter                     Kerala State   781
# 1794                   Zotter               Brazil, Mitzi Blue   486
#
#       Review Date Cocoa Percent Company Location  Rating Broad Bean Origin
# ...

# %%
#add na tp the blanks to drop them
no_bean_df["Broad Bean Origin"].replace("", np.nan, inplace=True)
no_bean_df
# Out:
#      Company (Maker-if known) Specific Bean Origin or Bar Name   REF  \
# 0                    A. Morin                      Agua Grande  1876
# 1                    A. Morin                            Kpime  1676
# 2                    A. Morin                           Atsane  1676
# 3                    A. Morin                            Akata  1680
# 4                    A. Morin                           Quilla  1704
# ...                       ...                              ...   ...
# 1790                   Zotter                             Peru   647
# 1791                   Zotter                            Congo   749
# 1792                   Zotter                     Kerala State   749
# 1793                   Zotter                     Kerala State   781
# 1794                   Zotter               Brazil, Mitzi Blue   486
#
#       Review Date Cocoa Percent Company Location  Rating Broad Bean Origin
# ...

# %%
#Drop any rows that don't contain all bean type & origin conditions. 
cacao_clean_df=no_bean_df.dropna()

cacao_clean_df
# Out:
#      Company (Maker-if known) Specific Bean Origin or Bar Name   REF  \
# 0                    A. Morin                      Agua Grande  1876
# 1                    A. Morin                            Kpime  1676
# 2                    A. Morin                           Atsane  1676
# 3                    A. Morin                            Akata  1680
# 4                    A. Morin                           Quilla  1704
# ...                       ...                              ...   ...
# 1790                   Zotter                             Peru   647
# 1791                   Zotter                            Congo   749
# 1792                   Zotter                     Kerala State   749
# 1793                   Zotter                     Kerala State   781
# 1794                   Zotter               Brazil, Mitzi Blue   486
#
#       Review Date Cocoa Percent Company Location  Rating Broad Bean Origin
# ...

# %%
# Export file as a CSV, without the Pandas index, but with the header
cacao_clean_df.to_csv("cacao_clean.csv", index=False, header=True)

# %%
first_cacao_df["Bean Type"].replace(" ", np.nan, inplace=True)
first_cacao_df
# Out:
#      Company (Maker-if known) Specific Bean Origin or Bar Name   REF  \
# 0                    A. Morin                      Agua Grande  1876
# 1                    A. Morin                            Kpime  1676
# 2                    A. Morin                           Atsane  1676
# 3                    A. Morin                            Akata  1680
# 4                    A. Morin                           Quilla  1704
# ...                       ...                              ...   ...
# 1790                   Zotter                             Peru   647
# 1791                   Zotter                            Congo   749
# 1792                   Zotter                     Kerala State   749
# 1793                   Zotter                     Kerala State   781
# 1794                   Zotter               Brazil, Mitzi Blue   486
#
#       Review Date Cocoa Percent Company Location  Rating  Bean Type  \
# 0            2016           63%           France    3.75        NaN
# ...

# %%
# Clean file with only dropna, keeping bean
cacaobean_dropna_df=first_cacao_df.dropna()
cacaobean_dropna_df
# Out:
#      Company (Maker-if known) Specific Bean Origin or Bar Name   REF  \
# 5                    A. Morin                         Carenero  1315
# 7                    A. Morin                     Sur del Lago  1315
# 8                    A. Morin                   Puerto Cabello  1319
# 11                   A. Morin                       Madagascar  1011
# 17                   A. Morin                            Chuao  1015
# ...                       ...                              ...   ...
# 1784                   Zotter                           El Oro   879
# 1785                   Zotter                     Huiwani Coop   879
# 1788                   Zotter                 Kongo, Highlands   883
# 1791                   Zotter                            Congo   749
# 1792                   Zotter                     Kerala State   749
#
#       Review Date Cocoa Percent Company Location  Rating  \
# 5            2014           70%           France    2.75
# ...

# %%
# Export file as a CSV, without the Pandas index, but with the header
cacaobean_dropna_df.to_csv("cacao_clean_withbean.csv", index=False, header=True)
