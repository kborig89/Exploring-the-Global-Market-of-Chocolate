# %%
# !pip install csv_to_sqlite

# %%
import sqlite3

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import csv_to_sqlite

# %%
first_cacao_df=pd.read_csv("flavors_of_cacao2.csv",encoding="utf-8")
first_cacao_df
# Out:
#      Company (Maker-if known) Specific Bean Origin or Bar Name   REF  \
# 0                    A. Morin                      Agua Grande  1876
# 1                    A. Morin                            Kpime  1676
# 2                    A. Morin                           Atsane  1676
# 3                    A. Morin                            Akata  1680
# 4                    A. Morin                           Quilla  1704
# ...                       ...                              ...   ...
# 1790                   Zotter                             Peru   647
# 1791                   Zotter                            Congo   749
# 1792                   Zotter                     Kerala State   749
# 1793                   Zotter                     Kerala State   781
# 1794                   Zotter               Brazil, Mitzi Blue   486
#
#       Review Date Cocoa Percent Company Location  Rating  Bean Type  \
# 0            2016           63%           France    3.75
# 1            2015           70%           France    2.75
# 2            2015           70%           France    3.00
# 3            2015           70%           France    3.50
# 4            2015           70%           France    3.50
# ...           ...           ...              ...     ...        ...
# 1790         2011           70%          Austria    3.75
# 1791         2011           65%          Austria    3.00  Forastero
# 1792         2011           65%          Austria    3.50  Forastero
# 1793         2011           62%          Austria    3.25
# 1794         2010           65%          Austria    3.00
#
#      Broad Bean Origin
# 0             Sao Tome
# 1                 Togo
# 2                 Togo
# 3                 Togo
# 4                 Peru
# ...                ...
# 1790              Peru
# 1791             Congo
# 1792             India
# 1793             India
# 1794            Brazil
#
# [1795 rows x 9 columns]

# %%
first_cacao_df["Bean Type"].replace(" ", np.nan, inplace=True)
first_cacao_df["Broad Bean Origin"].replace(" ", np.nan, inplace=True)
first_cacao_df
# Out:
#      Company (Maker-if known) Specific Bean Origin or Bar Name   REF  \
# 0                    A. Morin                      Agua Grande  1876
# 1                    A. Morin                            Kpime  1676
# 2                    A. Morin                           Atsane  1676
# 3                    A. Morin                            Akata  1680
# 4                    A. Morin                           Quilla  1704
# ...                       ...                              ...   ...
# 1790                   Zotter                             Peru   647
# 1791                   Zotter                            Congo   749
# 1792                   Zotter                     Kerala State   749
# 1793                   Zotter                     Kerala State   781
# 1794                   Zotter               Brazil, Mitzi Blue   486
#
#       Review Date Cocoa Percent Company Location  Rating  Bean Type  \
# 0            2016           63%           France    3.75        NaN
# 1            2015           70%           France    2.75        NaN
# 2            2015           70%           France    3.00        NaN
# 3            2015           70%           France    3.50        NaN
# 4            2015           70%           France    3.50        NaN
# ...           ...           ...              ...     ...        ...
# 1790         2011           70%          Austria    3.75        NaN
# 1791         2011           65%          Austria    3.00  Forastero
# 1792         2011           65%          Austria    3.50  Forastero
# 1793         2011           62%          Austria    3.25        NaN
# 1794         2010           65%          Austria    3.00        NaN
#
#      Broad Bean Origin
# 0             Sao Tome
# 1                 Togo
# 2                 Togo
# 3                 Togo
# 4                 Peru
# ...                ...
# 1790              Peru
# 1791             Congo
# 1792             India
# 1793             India
# 1794            Brazil
#
# [1795 rows x 9 columns]

# %%
first_cacao_df = first_cacao_df.rename(columns={'Company (Maker-if known)': "company", 'Specific Bean Origin or Bar Name': "specific_bean_origin",
       'Review Date': "review_date", 'Cocoa Percent': "cocoa_percent", 'Company Location': "company_location", 'Rating': "rating",
       'Bean Type': "bean_type", 'Broad Bean Origin': "bean_origin_country"})
first_cacao_df
# Out:
#        company specific_bean_origin   REF  review_date cocoa_percent  \
# 0     A. Morin          Agua Grande  1876         2016           63%
# 1     A. Morin                Kpime  1676         2015           70%
# 2     A. Morin               Atsane  1676         2015           70%
# 3     A. Morin                Akata  1680         2015           70%
# 4     A. Morin               Quilla  1704         2015           70%
# ...        ...                  ...   ...          ...           ...
# 1790    Zotter                 Peru   647         2011           70%
# 1791    Zotter                Congo   749         2011           65%
# 1792    Zotter         Kerala State   749         2011           65%
# 1793    Zotter         Kerala State   781         2011           62%
# 1794    Zotter   Brazil, Mitzi Blue   486         2010           65%
#
#      company_location  rating  bean_type bean_origin_country
# 0              France    3.75        NaN            Sao Tome
# 1              France    2.75        NaN                Togo
# 2              France    3.00        NaN                Togo
# 3              France    3.50        NaN                Togo
# 4              France    3.50        NaN                Peru
# ...               ...     ...        ...                 ...
# 1790          Austria    3.75        NaN                Peru
# 1791          Austria    3.00  Forastero               Congo
# 1792          Austria    3.50  Forastero               India
# 1793          Austria    3.25        NaN               India
# 1794          Austria    3.00        NaN              Brazil
#
# [1795 rows x 9 columns]

# %%
first_cacao_df.columns
# Out:
# Index(['company', 'specific_bean_origin', 'REF', 'review_date',
#        'cocoa_percent', 'company_location', 'rating', 'bean_type',
#        'bean_origin_country'],
#       dtype='object')

# %%
#drop bean column
no_bean_df=first_cacao_df.loc[:, ['company', 'specific_bean_origin', 'review_date', 'cocoa_percent',
       'company_location', 'rating', 'bean_origin_country']]

no_bean_df
# Out:
#        company specific_bean_origin  review_date cocoa_percent  \
# 0     A. Morin          Agua Grande         2016           63%
# 1     A. Morin                Kpime         2015           70%
# 2     A. Morin               Atsane         2015           70%
# 3     A. Morin                Akata         2015           70%
# 4     A. Morin               Quilla         2015           70%
# ...        ...                  ...          ...           ...
# 1790    Zotter                 Peru         2011           70%
# 1791    Zotter                Congo         2011           65%
# 1792    Zotter         Kerala State         2011           65%
# 1793    Zotter         Kerala State         2011           62%
# 1794    Zotter   Brazil, Mitzi Blue         2010           65%
#
#      company_location  rating bean_origin_country
# 0              France    3.75            Sao Tome
# 1              France    2.75                Togo
# 2              France    3.00                Togo
# 3              France    3.50                Togo
# 4              France    3.50                Peru
# ...               ...     ...                 ...
# 1790          Austria    3.75                Peru
# 1791          Austria    3.00               Congo
# 1792          Austria    3.50               India
# 1793          Austria    3.25               India
# 1794          Austria    3.00              Brazil
#
# [1795 rows x 7 columns]

# %%
#Drop any rows that don't contain all bean type & origin conditions. 
cacao_clean_df=no_bean_df.dropna()

cacao_clean_df
# Out:
#        company specific_bean_origin  review_date cocoa_percent  \
# 0     A. Morin          Agua Grande         2016           63%
# 1     A. Morin                Kpime         2015           70%
# 2     A. Morin               Atsane         2015           70%
# 3     A. Morin                Akata         2015           70%
# 4     A. Morin               Quilla         2015           70%
# ...        ...                  ...          ...           ...
# 1790    Zotter                 Peru         2011           70%
# 1791    Zotter                Congo         2011           65%
# 1792    Zotter         Kerala State         2011           65%
# 1793    Zotter         Kerala State         2011           62%
# 1794    Zotter   Brazil, Mitzi Blue         2010           65%
#
#      company_location  rating bean_origin_country
# 0              France    3.75            Sao Tome
# 1              France    2.75                Togo
# 2              France    3.00                Togo
# 3              France    3.50                Togo
# 4              France    3.50                Peru
# ...               ...     ...                 ...
# 1790          Austria    3.75                Peru
# 1791          Austria    3.00               Congo
# 1792          Austria    3.50               India
# 1793          Austria    3.25               India
# 1794          Austria    3.00              Brazil
#
# [1721 rows x 7 columns]

# %%
# Export file as a CSV, without the Pandas index, but with the header
cacao_clean_df.to_csv("cacao_clean.csv", index=False, header=True)

# %%
# Clean file with only dropna, keeping bean
cacaobean_dropna_df=first_cacao_df.dropna()
cacaobean_dropna_df
# Out:
#        company specific_bean_origin   REF  review_date cocoa_percent  \
# 5     A. Morin             Carenero  1315         2014           70%
# 7     A. Morin         Sur del Lago  1315         2014           70%
# 8     A. Morin       Puerto Cabello  1319         2014           70%
# 11    A. Morin           Madagascar  1011         2013           70%
# 17    A. Morin                Chuao  1015         2013           70%
# ...        ...                  ...   ...          ...           ...
# 1784    Zotter               El Oro   879         2012           75%
# 1785    Zotter         Huiwani Coop   879         2012           75%
# 1788    Zotter     Kongo, Highlands   883         2012           68%
# 1791    Zotter                Congo   749         2011           65%
# 1792    Zotter         Kerala State   749         2011           65%
#
#      company_location  rating             bean_type bean_origin_country
# 5              France    2.75               Criollo           Venezuela
# 7              France    3.50               Criollo           Venezuela
# 8              France    3.75               Criollo           Venezuela
# 11             France    3.00               Criollo          Madagascar
# 17             France    4.00            Trinitario           Venezuela
# ...               ...     ...                   ...                 ...
# 1784          Austria    3.00  Forastero (Nacional)             Ecuador
# 1785          Austria    3.00   Criollo, Trinitario    Papua New Guinea
# 1788          Austria    3.25             Forastero               Congo
# 1791          Austria    3.00             Forastero               Congo
# 1792          Austria    3.50             Forastero               India
#
# [884 rows x 9 columns]

# %%
#drop bean column
first_cacao_df=first_cacao_df.loc[:, ['company', 'specific_bean_origin', 'review_date', 'cocoa_percent',
       'company_location', 'rating', 'bean_type', 'bean_origin_country']]

first_cacao_df
# Out:
#        company specific_bean_origin  review_date cocoa_percent  \
# 0     A. Morin          Agua Grande         2016           63%
# 1     A. Morin                Kpime         2015           70%
# 2     A. Morin               Atsane         2015           70%
# 3     A. Morin                Akata         2015           70%
# 4     A. Morin               Quilla         2015           70%
# ...        ...                  ...          ...           ...
# 1790    Zotter                 Peru         2011           70%
# 1791    Zotter                Congo         2011           65%
# 1792    Zotter         Kerala State         2011           65%
# 1793    Zotter         Kerala State         2011           62%
# 1794    Zotter   Brazil, Mitzi Blue         2010           65%
#
#      company_location  rating  bean_type bean_origin_country
# 0              France    3.75        NaN            Sao Tome
# 1              France    2.75        NaN                Togo
# 2              France    3.00        NaN                Togo
# 3              France    3.50        NaN                Togo
# 4              France    3.50        NaN                Peru
# ...               ...     ...        ...                 ...
# 1790          Austria    3.75        NaN                Peru
# 1791          Austria    3.00  Forastero               Congo
# 1792          Austria    3.50  Forastero               India
# 1793          Austria    3.25        NaN               India
# 1794          Austria    3.00        NaN              Brazil
#
# [1795 rows x 8 columns]

# %%
# Clean file with only dropna, keeping bean
# cacaobean_dropna_df=first_cacao_df.dropna()

# cacaobean_dropna_df.reset_index(drop=True)

first_cacao_df.index.name = 'id'
# Export file as a CSV, without the Pandas index, but with the header
first_cacao_df.to_csv("cacao_clean_withbean.csv", index=True, header=True)

# %%
import csv_to_sqlite 
# all the usual options are supported
options = csv_to_sqlite.CsvOptions(typing_style="full", encoding="utf-8") 
input_files = ["cacao_clean_withbean.csv"] # pass in a list of CSV files
csv_to_sqlite.write_csv(input_files, "cacao_bean.sqlite", options)
# Out:
# Written 1795 rows into 1 tables in 0.091 seconds
# 1795

# %%
conn = sqlite3.connect("cacao_bean.sqlite")

# %%
cur = conn.cursor()
cur.execute("SELECT * FROM cacao_clean_withbean")
cur.fetchall()
# Out:
# [(0, 'A. Morin', 'Agua Grande', 2016, '63%', 'France', 3.75, '', 'Sao Tome'),
#  (1, 'A. Morin', 'Kpime', 2015, '70%', 'France', 2.75, '', 'Togo'),
#  (2, 'A. Morin', 'Atsane', 2015, '70%', 'France', 3.0, '', 'Togo'),
#  (3, 'A. Morin', 'Akata', 2015, '70%', 'France', 3.5, '', 'Togo'),
#  (4, 'A. Morin', 'Quilla', 2015, '70%', 'France', 3.5, '', 'Peru'),
#  (5,
#   'A. Morin',
#   'Carenero',
#   2014,
#   '70%',
#   'France',
#   2.75,
#   'Criollo',
#   'Venezuela'),
#  (6, 'A. Morin', 'Cuba', 2014, '70%', 'France', 3.5, '', 'Cuba'),
#  (7,
#   'A. Morin',
#   'Sur del Lago',
#   2014,
#   '70%',
#   'France',
#   3.5,
#   'Criollo',
#   'Venezuela'),
#  (8,
#   'A. Morin',
#   'Puerto Cabello',
#   2014,
#   '70%',
#   'France',
#   3.75,
#   'Criollo',
#   'Venezuela'),
#  (9, 'A. Morin', 'Pablino', 2014, '70%', 'France', 4.0, '', 'Peru'),
#  (10, 'A. Morin', 'Panama', 2013, '70%', 'France', 2.75, '', 'Panama'),
#  (11,
#   'A. Morin',
#   'Madagascar',
#   2013,
#   '70%',
#   'France',
#   3.0,
#   'Criollo',
#   'Madagascar'),
#  (12, 'A. Morin', 'Brazil', 2013, '70%', 'France', 3.25, '', 'Brazil'),
#  (13, 'A. Morin', 'Equateur', 2013, '70%', 'France', 3.75, '', 'Ecuador'),
#  (14, 'A. Morin', 'Colombie', 2013, '70%', 'France', 2.75, '', 'Colombia'),
#  (15, 'A. Morin', 'Birmanie', 2013, '70%', 'France', 3.0, '', 'Burma'),
#  (16,
#   'A. Morin',
#   'Papua New Guinea',
#   2013,
#   '70%',
#   'France',
#   3.25,
#   '',
#   'Papua New Guinea'),
#  (17,
#   'A. Morin',
#   'Chuao',
#   2013,
#   '70%',
#   'France',
#   4.0,
#   'Trinitario',
#   'Venezuela'),
#  (18, 'A. Morin', 'Piura', 2013, '70%', 'France', 3.25, '', 'Peru'),
#  (19,
#   'A. Morin',
#   'Chanchamayo Province',
#   2013,
#   '70%',
#   'France',
#   3.5,
#   '',
#   'Peru'),
#  (20,
#   'A. Morin',
#   'Chanchamayo Province',
#   2013,
#   '63%',
#   'France',
#   4.0,
#   '',
#   'Peru'),
#  (21, 'A. Morin', 'Bolivia', 2012, '70%', 'France', 3.5, '', 'Bolivia'),
#  (22, 'A. Morin', 'Peru', 2012, '63%', 'France', 3.75, '', 'Peru'),
#  (23,
#   'Acalli',
#   'Chulucanas, El Platanal',
#   2015,
#   '70%',
#   'U.S.A.',
#   3.75,
#   '',
#   'Peru'),
#  (24,
#   'Acalli',
#   'Tumbes, Norandino',
#   2015,
#   '70%',
#   'U.S.A.',
#   3.75,
#   'Criollo',
#   'Peru'),
#  (25, 'Adi', 'Vanua Levu', 2011, '60%', 'Fiji', 2.75, 'Trinitario', 'Fiji'),
#  (26,
#   'Adi',
#   'Vanua Levu, Toto-A',
#   2011,
#   '80%',
#   'Fiji',
#   3.25,
#   'Trinitario',
#   'Fiji'),
#  (27, 'Adi', 'Vanua Levu', 2011, '88%', 'Fiji', 3.5, 'Trinitario', 'Fiji'),
#  (28,
#   'Adi',
#   'Vanua Levu, Ami-Ami-CA',
#   2011,
#   '72%',
#   'Fiji',
#   3.5,
#   'Trinitario',
#   'Fiji'),
#  (29,
#   'Aequare (Gianduja)',
#   'Los Rios, Quevedo, Arriba',
#   2009,
#   '55%',
#   'Ecuador',
#   2.75,
#   'Forastero (Arriba)',
#   'Ecuador'),
#  (30,
#   'Aequare (Gianduja)',
#   'Los Rios, Quevedo, Arriba',
#   2009,
#   '70%',
#   'Ecuador',
#   3.0,
#   'Forastero (Arriba)',
#   'Ecuador'),
#  (31, 'Ah Cacao', 'Tabasco', 2009, '70%', 'Mexico', 3.0, 'Criollo', 'Mexico'),
#  (32,
#   "Akesson's (Pralus)",
#   'Bali (west), Sukrama Family, Melaya area',
#   2011,
#   '75%',
#   'Switzerland',
#   3.75,
#   'Trinitario',
#   'Indonesia'),
#  (33,
#   "Akesson's (Pralus)",
#   'Madagascar, Ambolikapiky P.',
#   2010,
#   '75%',
#   'Switzerland',
#   2.75,
#   'Criollo',
#   'Madagascar'),
#  (34,
#   "Akesson's (Pralus)",
#   'Monte Alegre, D. Badero',
#   2010,
#   '75%',
#   'Switzerland',
#   2.75,
#   'Forastero',
#   'Brazil'),
#  (35,
#   'Alain Ducasse',
#   'Trinite',
#   2014,
#   '65%',
#   'France',
#   2.75,
#   'Trinitario',
#   'Trinidad'),
#  (36,
#   'Alain Ducasse',
#   'Vietnam',
#   2014,
#   '75%',
#   'France',
#   2.75,
#   'Trinitario',
#   'Vietnam'),
#  (37,
#   'Alain Ducasse',
#   'Madagascar',
#   2014,
#   '75%',
#   'France',
#   3.0,
#   'Trinitario',
#   'Madagascar'),
#  (38,
#   'Alain Ducasse',
#   'Chuao',
#   2013,
#   '75%',
#   'France',
#   2.5,
#   'Trinitario',
#   'Venezuela'),
#  (39, 'Alain Ducasse', 'Piura, Perou', 2013, '75%', 'France', 2.5, '', 'Peru'),
#  (40,
#   'Alexandre',
#   'Winak Coop, Napo',
#   2017,
#   '70%',
#   'Netherlands',
#   3.5,
#   'Forastero (Nacional)',
#   'Ecuador'),
#  (41,
#   'Alexandre',
#   'La Dalia, Matagalpa',
#   2017,
#   '70%',
#   'Netherlands',
#   3.5,
#   'Criollo, Trinitario',
#   'Nicaragua'),
#  (42,
#   'Alexandre',
#   'Tien Giang',
#   2017,
#   '70%',
#   'Netherlands',
#   3.5,
#   'Trinitario',
#   'Vietnam'),
#  (43,
#   'Alexandre',
#   'Makwale Village, Kyela',
#   2017,
#   '70%',
#   'Netherlands',
#   3.5,
#   'Forastero',
#   'Tanzania'),
#  (44,
#   'Altus aka Cao Artisan',
#   'Momotombo',
#   2016,
#   '60%',
#   'U.S.A.',
#   2.75,
#   '',
#   'Nicaragua'),
#  (45,
#   'Altus aka Cao Artisan',
#   'Acopagro',
#   2016,
#   '60%',
#   'U.S.A.',
#   3.0,
#   '',
#   'Peru'),
#  (46,
#   'Altus aka Cao Artisan',
#   'CIAAB Coop',
#   2016,
#   '60%',
#   'U.S.A.',
#   2.5,
#   '',
#   'Bolivia'),
#  (47,
#   'Altus aka Cao Artisan',
#   'Villa Andina',
#   2016,
#   '60%',
#   'U.S.A.',
#   2.5,
#   '',
#   'Peru'),
#  (48,
#   'Altus aka Cao Artisan',
#   'Gruppo Salinas',
#   2016,
#   '60%',
#   'U.S.A.',
#   2.75,
#   '',
#   'Ecuador'),
#  (49,
#   'Altus aka Cao Artisan',
#   'Sur del Lago',
#   2013,
#   '60%',
#   'U.S.A.',
#   2.5,
#   '',
#   'Venezuela'),
#  (50,
#   'Altus aka Cao Artisan',
#   'Conacado',
#   2013,
#   '60%',
#   'U.S.A.',
#   3.0,
#   'Trinitario',
#   'Dominican Republic'),
#  (51,
#   'Altus aka Cao Artisan',
#   'Bolivia',
#   2013,
#   '80%',
#   'U.S.A.',
#   3.25,
#   '',
#   'Bolivia'),
#  (52,
#   'Altus aka Cao Artisan',
#   'Bolivia',
#   2013,
#   '60%',
#   'U.S.A.',
#   3.0,
#   '',
#   'Bolivia'),
#  (53,
#   'Altus aka Cao Artisan',
#   'Peru',
#   2013,
#   '60%',
#   'U.S.A.',
#   3.25,
#   '',
#   'Peru'),
#  (54, 'Amano', 'Morobe', 2011, '70%', 'U.S.A.', 4.0, '', 'Papua New Guinea'),
#  (55,
#   'Amano',
#   'Dos Rios',
#   2010,
#   '70%',
#   'U.S.A.',
#   3.75,
#   '',
#   'Dominican Republic'),
#  (56, 'Amano', 'Guayas', 2010, '70%', 'U.S.A.', 4.0, '', 'Ecuador'),
#  (57, 'Amano', 'Chuao', 2010, '70%', 'U.S.A.', 3.0, 'Trinitario', 'Venezuela'),
#  (58, 'Amano', 'Montanya', 2009, '70%', 'U.S.A.', 3.0, '', 'Venezuela'),
#  (59, 'Amano', 'Bali, Jembrana', 2008, '70%', 'U.S.A.', 2.75, '', 'Indonesia'),
#  (60,
#   'Amano',
#   'Madagascar',
#   2007,
#   '70%',
#   'U.S.A.',
#   3.5,
#   'Trinitario',
#   'Madagascar'),
#  (61, 'Amano', 'Cuyagua', 2007, '70%', 'U.S.A.', 3.0, '', 'Venezuela'),
#  (62, 'Amano', 'Ocumare', 2007, '70%', 'U.S.A.', 3.75, 'Criollo', 'Venezuela'),
#  (63,
#   'Amatller (Simon Coll)',
#   'Ghana',
#   2009,
#   '70%',
#   'Spain',
#   3.0,
#   'Forastero',
#   'Ghana'),
#  (64,
#   'Amatller (Simon Coll)',
#   'Ecuador',
#   2009,
#   '70%',
#   'Spain',
#   2.75,
#   '',
#   'Ecuador'),
#  (65,
#   'Amatller (Simon Coll)',
#   'Ecuador',
#   2009,
#   '85%',
#   'Spain',
#   2.75,
#   '',
#   'Ecuador'),
#  (66,
#   'Amatller (Simon Coll)',
#   'Ghana',
#   2009,
#   '85%',
#   'Spain',
#   3.0,
#   'Forastero',
#   'Ghana'),
#  (67,
#   'Amazona',
#   'LamasdelChanka, San Martin, Oro Verde coop',
#   2013,
#   '72%',
#   'Peru',
#   3.25,
#   '',
#   'Peru'),
#  (68,
#   'Amazona',
#   'Bellavista Gran Pajeten, San Martin',
#   2013,
#   '73%',
#   'Peru',
#   3.5,
#   'Trinitario',
#   'Peru'),
#  (69,
#   'Ambrosia',
#   'Belize',
#   2015,
#   '64%',
#   'Canada',
#   3.0,
#   'Trinitario',
#   'Belize'),
#  (70,
#   'Ambrosia',
#   'Madagascar',
#   2015,
#   '66%',
#   'Canada',
#   3.25,
#   'Trinitario',
#   'Madagascar'),
#  (71,
#   'Ambrosia',
#   'Dominican Republic',
#   2015,
#   '75%',
#   'Canada',
#   3.25,
#   '',
#   'Dominican Republic'),
#  (72,
#   'Ambrosia',
#   'Papua New Guinea',
#   2015,
#   '63%',
#   'Canada',
#   3.25,
#   '',
#   'Papua New Guinea'),
#  (73, 'Ambrosia', 'Venezuela', 2015, '70%', 'Canada', 3.25, '', 'Venezuela'),
#  (74, 'Ambrosia', 'Peru', 2015, '68%', 'Canada', 3.5, '', 'Peru'),
#  (75,
#   'Amedei',
#   'Piura, Blanco de Criollo',
#   2012,
#   '70%',
#   'Italy',
#   3.75,
#   '',
#   'Peru'),
#  (76,
#   'Amedei',
#   'Porcelana',
#   2007,
#   '70%',
#   'Italy',
#   4.0,
#   'Criollo (Porcelana)',
#   'Venezuela'),
#  (77, 'Amedei', 'Nine', 2007, '75%', 'Italy', 4.0, 'Blend', ''),
#  (78, 'Amedei', 'Chuao', 2007, '70%', 'Italy', 5.0, 'Trinitario', 'Venezuela'),
#  (79, 'Amedei', 'Ecuador', 2007, '70%', 'Italy', 3.0, 'Trinitario', 'Ecuador'),
#  (80, 'Amedei', 'Jamaica', 2007, '70%', 'Italy', 3.0, 'Trinitario', 'Jamaica'),
#  (81, 'Amedei', 'Grenada', 2007, '70%', 'Italy', 3.5, 'Trinitario', 'Grenada'),
#  (82,
#   'Amedei',
#   'Venezuela',
#   2007,
#   '70%',
#   'Italy',
#   3.75,
#   'Trinitario (85% Criollo)',
#   'Venezuela'),
#  (83,
#   'Amedei',
#   'Madagascar',
#   2007,
#   '70%',
#   'Italy',
#   4.0,
#   'Trinitario (85% Criollo)',
#   'Madagascar'),
#  (84,
#   'Amedei',
#   'Trinidad',
#   2007,
#   '70%',
#   'Italy',
#   3.5,
#   'Trinitario',
#   'Trinidad'),
#  (85, 'Amedei', 'Toscano Black', 2007, '63%', 'Italy', 3.5, 'Blend', ''),
#  (86, 'Amedei', 'Toscano Black', 2006, '70%', 'Italy', 5.0, 'Blend', ''),
#  (87, 'Amedei', 'Toscano Black', 2006, '66%', 'Italy', 4.0, 'Blend', ''),
#  (88,
#   'AMMA',
#   'Catongo',
#   2013,
#   '75%',
#   'Brazil',
#   3.25,
#   'Forastero (Catongo)',
#   'Brazil'),
#  (89,
#   'AMMA',
#   'Monte Alegre, 3 diff. plantations',
#   2010,
#   '85%',
#   'Brazil',
#   2.75,
#   'Forastero (Parazinho)',
#   'Brazil'),
#  (90,
#   'AMMA',
#   'Monte Alegre, 3 diff. plantations',
#   2010,
#   '50%',
#   'Brazil',
#   3.75,
#   'Forastero (Parazinho)',
#   'Brazil'),
#  (91,
#   'AMMA',
#   'Monte Alegre, 3 diff. plantations',
#   2010,
#   '75%',
#   'Brazil',
#   3.75,
#   'Forastero (Parazinho)',
#   'Brazil'),
#  (92,
#   'AMMA',
#   'Monte Alegre, 3 diff. plantations',
#   2010,
#   '60%',
#   'Brazil',
#   4.0,
#   'Forastero (Parazinho)',
#   'Brazil'),
#  (93,
#   'Anahata',
#   'Elvesia',
#   2014,
#   '75%',
#   'U.S.A.',
#   3.0,
#   '',
#   'Dominican Republic'),
#  (94, 'Animas', 'Alto Beni', 2016, '75%', 'U.S.A.', 3.5, '', 'Bolivia'),
#  (95,
#   'Ara',
#   'Madagascar',
#   2014,
#   '75%',
#   'France',
#   3.0,
#   'Trinitario',
#   'Madagascar'),
#  (96, 'Ara', 'Chiapas', 2014, '72%', 'France', 2.5, '', 'Mexico'),
#  (97, 'Ara', 'Equateur', 2014, '75%', 'France', 2.75, '', 'Ecuador'),
#  (98, 'Ara', 'Trincheras', 2014, '75%', 'France', 3.0, '', 'Venezuela'),
#  (99,
#   'Arete',
#   'San Juan',
#   2016,
#   '70%',
#   'U.S.A.',
#   3.5,
#   'Trinitario',
#   'Trinidad'),
#  (100, 'Arete', 'Kokoa Kamili', 2016, '70%', 'U.S.A.', 3.75, '', 'Tanzania'),
#  (101,
#   'Arete',
#   'Tien Giang',
#   2016,
#   '73%',
#   'U.S.A.',
#   3.5,
#   'Trinitario',
#   'Vietnam'),
#  (102,
#   'Arete',
#   'Hacienda Victoria',
#   2016,
#   '70%',
#   'U.S.A.',
#   3.25,
#   '',
#   'Ecuador'),
#  (103,
#   'Arete',
#   'Costa Esmeraldas',
#   2016,
#   '70%',
#   'U.S.A.',
#   3.25,
#   '',
#   'Ecuador'),
#  (104, 'Arete', 'Lachua', 2016, '70%', 'U.S.A.', 3.5, '', 'Guatemala'),
#  (105, 'Arete', 'Rugoso', 2016, '70%', 'U.S.A.', 3.75, '', 'Nicaragua'),
#  (106, 'Arete', 'La Masica, FHIA', 2016, '70%', 'U.S.A.', 3.5, '', 'Honduras'),
#  (107,
#   'Arete',
#   'Coto Brus, Terciopelo',
#   2016,
#   '70%',
#   'U.S.A.',
#   4.0,
#   '',
#   'Costa Rica'),
#  (108,
#   'Arete',
#   'Phantom',
#   2016,
#   '70%',
#   'U.S.A.',
#   4.0,
#   'Forastero (Nacional)',
#   'Peru'),
#  (109,
#   'Arete',
#   'Elvesia',
#   2016,
#   '70%',
#   'U.S.A.',
#   3.75,
#   '',
#   'Dominican Republic'),
#  (110, 'Arete', 'Matasawalevu', 2016, '70%', 'U.S.A.', 3.25, '', 'Fiji'),
#  (111, 'Arete', 'Lam Dong', 2016, '73%', 'U.S.A.', 3.25, '', 'Vietnam'),
#  (112, 'Arete', 'Fazenda Camboa', 2015, '70%', 'U.S.A.', 3.5, '', 'Brazil'),
#  (113,
#   'Arete',
#   'Nacional',
#   2015,
#   '68%',
#   'U.S.A.',
#   3.5,
#   'Forastero (Nacional)',
#   'Peru'),
#  (114,
#   'Arete',
#   'Puerto Quito, heirloom',
#   2015,
#   '70%',
#   'U.S.A.',
#   3.75,
#   'Forastero (Nacional)',
#   'Ecuador'),
#  (115,
#   'Arete',
#   'Oko Caribe',
#   2015,
#   '70%',
#   'U.S.A.',
#   3.5,
#   '',
#   'Domincan Republic'),
#  (116,
#   'Arete',
#   'Maya Mountain',
#   2015,
#   '70%',
#   'U.S.A.',
#   3.75,
#   'Trinitario',
#   'Belize'),
#  (117,
#   'Arete',
#   'Chuno',
#   2015,
#   '70%',
#   'U.S.A.',
#   4.0,
#   'Criollo, Trinitario',
#   'Nicaragua'),
#  (118, 'Arete', 'Fazenda Camboa', 2015, '75%', 'U.S.A.', 2.75, '', 'Brazil'),
#  (119, 'Arete', 'Guatemala', 2015, '70%', 'U.S.A.', 3.25, '', 'Guatemala'),
#  (120, 'Arete', 'Camino Verde', 2015, '75%', 'U.S.A.', 3.5, '', 'Ecuador'),
#  (121,
#   'Artisan du Chocolat',
#   'Trinidad, Heritage, Limited ed.',
#   2013,
#   '72%',
#   'U.K.',
#   3.25,
#   'Trinitario',
#   'Trinidad'),
#  (122,
#   'Artisan du Chocolat',
#   'Colombia, Casa Luker',
#   2012,
#   '72%',
#   'U.K.',
#   3.75,
#   '',
#   'Colombia'),
#  (123, 'Artisan du Chocolat', 'Haiti', 2011, '72%', 'U.K.', 4.0, '', 'Haiti'),
#  (124,
#   'Artisan du Chocolat',
#   'Panama',
#   2011,
#   '72%',
#   'U.K.',
#   2.75,
#   '',
#   'Panama'),
#  (125,
#   'Artisan du Chocolat',
#   'Venezuela',
#   2010,
#   '100%',
#   'U.K.',
#   1.75,
#   '',
#   'Venezuela'),
#  (126,
#   'Artisan du Chocolat',
#   'Jamaica',
#   2010,
#   '72%',
#   'U.K.',
#   3.75,
#   'Trinitario',
#   'Jamaica'),
#  (127,
#   'Artisan du Chocolat',
#   'Costa Rica',
#   2010,
#   '72%',
#   'U.K.',
#   3.25,
#   '',
#   'Costa Rica'),
#  (128,
#   'Artisan du Chocolat',
#   'Ba Ria Vung Tau Province',
#   2010,
#   '72%',
#   'U.K.',
#   3.25,
#   'Trinitario',
#   'Vietnam'),
#  (129,
#   'Artisan du Chocolat',
#   'Bali',
#   2010,
#   '72%',
#   'U.K.',
#   3.5,
#   '',
#   'Indonesia'),
#  (130,
#   'Artisan du Chocolat',
#   'Ocumare, Venezuela',
#   2009,
#   '75%',
#   'U.K.',
#   2.5,
#   'Criollo, Trinitario',
#   'Venezuela'),
#  (131,
#   'Artisan du Chocolat',
#   'Java',
#   2009,
#   '72%',
#   'U.K.',
#   2.75,
#   'Trinitario',
#   'Indonesia'),
#  (132,
#   'Artisan du Chocolat',
#   'Brazil Rio Doce',
#   2009,
#   '72%',
#   'U.K.',
#   1.75,
#   '',
#   'Brazil'),
#  (133,
#   'Artisan du Chocolat',
#   'Madagascar',
#   2009,
#   '80%',
#   'U.K.',
#   3.0,
#   'Criollo, Trinitario',
#   'Madagascar'),
#  (134,
#   'Artisan du Chocolat',
#   'Peru',
#   2009,
#   '75%',
#   'U.K.',
#   3.0,
#   'Criollo',
#   'Peru'),
#  (135,
#   'Artisan du Chocolat',
#   'Dominican Republic',
#   2009,
#   '72%',
#   'U.K.',
#   3.25,
#   'Trinitario',
#   'Dominican Republic'),
#  (136,
#   'Artisan du Chocolat',
#   'Congo',
#   2008,
#   '72%',
#   'U.K.',
#   3.75,
#   'Forastero',
#   'Congo'),
#  (137,
#   'Artisan du Chocolat (Casa Luker)',
#   'Orinoqua Region, Arauca',
#   2013,
#   '72%',
#   'U.K.',
#   2.75,
#   'Trinitario',
#   'Colombia'),
#  (138,
#   'Askinosie',
#   'Mababa',
#   2016,
#   '68%',
#   'U.S.A.',
#   3.75,
#   'Trinitario',
#   'Tanzania'),
#  (139,
#   'Askinosie',
#   'Tenende, Uwate',
#   2011,
#   '72%',
#   'U.S.A.',
#   3.75,
#   'Trinitario',
#   'Tanzania'),
#  (140,
#   'Askinosie',
#   'Cortes',
#   2011,
#   '70%',
#   'U.S.A.',
#   3.75,
#   'Trinitario',
#   'Honduras'),
#  (141,
#   'Askinosie',
#   'Davao',
#   2009,
#   '77%',
#   'U.S.A.',
#   3.75,
#   'Trinitario',
#   'Philippines'),
#  (142,
#   'Askinosie',
#   'Xoconusco',
#   2007,
#   '75%',
#   'U.S.A.',
#   2.5,
#   'Trinitario',
#   'Mexico'),
#  (143,
#   'Askinosie',
#   'San Jose del Tambo',
#   2007,
#   '70%',
#   'U.S.A.',
#   3.0,
#   'Forastero (Arriba)',
#   'Ecuador'),
#  (144, 'Bahen & Co.', 'Houseblend', 2015, '80%', 'Australia', 3.25, '', ''),
#  (145,
#   'Bahen & Co.',
#   'Papua New Guinea',
#   2015,
#   '70%',
#   'Australia',
#   3.5,
#   '',
#   'Papua New Guinea'),
#  (146,
#   'Bahen & Co.',
#   'Sambirano',
#   2012,
#   '70%',
#   'Australia',
#   3.0,
#   'Trinitario',
#   'Madagascar'),
#  (147, 'Bahen & Co.', 'Bahia', 2012, '70%', 'Australia', 2.5, '', 'Brazil'),
#  (148,
#   'Bahen & Co.',
#   'Houseblend',
#   2012,
#   '70%',
#   'Australia',
#   2.5,
#   'Blend',
#   ''),
#  (149, 'Bakau', 'Bambamarca, 2015', 2015, '70%', 'Peru', 2.75, '', 'Peru'),
#  (150, 'Bakau', 'Huallabamba, 2015', 2015, '70%', 'Peru', 3.5, '', 'Peru'),
#  (151, 'Bar Au Chocolat', 'Bahia', 2015, '70%', 'U.S.A.', 3.5, '', 'Brazil'),
#  (152,
#   'Bar Au Chocolat',
#   'Maranon Canyon',
#   2014,
#   '70%',
#   'U.S.A.',
#   4.0,
#   'Forastero (Nacional)',
#   'Peru'),
#  (153,
#   'Bar Au Chocolat',
#   'Duarte Province',
#   2012,
#   '70%',
#   'U.S.A.',
#   3.25,
#   '',
#   'Dominican Republic'),
#  (154, 'Bar Au Chocolat', 'Chiapas', 2012, '70%', 'U.S.A.', 3.5, '', 'Mexico'),
#  (155,
#   'Bar Au Chocolat',
#   'Sambirano',
#   2012,
#   '70%',
#   'U.S.A.',
#   3.75,
#   'Trinitario',
#   'Madagascar'),
#  (156,
#   "Baravelli's",
#   'single estate',
#   2012,
#   '80%',
#   'Wales',
#   2.75,
#   '',
#   'Costa Rica'),
#  (157,
#   'Batch',
#   'Dominican Republic, Batch 3',
#   2016,
#   '65%',
#   'U.S.A.',
#   3.5,
#   '',
#   'Domincan Republic'),
#  (158, 'Batch', 'Brazil', 2016, '70%', 'U.S.A.', 3.75, '', 'Brazil'),
#  (159, 'Batch', 'Ecuador', 2016, '65%', 'U.S.A.', 3.25, '', 'Ecuador'),
#  (160,
#   'Beau Cacao',
#   'Asajaya E, NW Borneo, b. #132/4500',
#   2017,
#   '73%',
#   'U.K.',
#   3.0,
#   '',
#   'Malaysia'),
#  (161,
#   'Beau Cacao',
#   'Serian E., NW Borneo, b. #134/3800',
#   2017,
#   '72%',
#   'U.K.',
#   3.25,
#   '',
#   'Malaysia'),
#  (162,
#   'Beehive',
#   'Brazil, Batch 20316',
#   2016,
#   '80%',
#   'U.S.A.',
#   2.75,
#   '',
#   'Brazil'),
#  (163,
#   'Beehive',
#   'Dominican Republic, Batch 31616',
#   2016,
#   '70%',
#   'U.S.A.',
#   2.75,
#   '',
#   'Domincan Republic'),
#  (164,
#   'Beehive',
#   'Ecuador, Batch 31516',
#   2016,
#   '70%',
#   'U.S.A.',
#   2.75,
#   '',
#   'Ecuador'),
#  (165, 'Beehive', 'Ecuador', 2016, '90%', 'U.S.A.', 2.75, '', 'Ecuador'),
#  (166,
#   'Belcolade',
#   'Costa Rica',
#   2010,
#   '64%',
#   'Belgium',
#   2.75,
#   '',
#   'Costa Rica'),
#  (167,
#   'Belcolade',
#   'Papua New Guinea',
#   2010,
#   '64%',
#   'Belgium',
#   2.75,
#   '',
#   'Papua New Guinea'),
#  (168, 'Belcolade', 'Peru', 2010, '64%', 'Belgium', 2.75, '', 'Peru'),
#  (169, 'Belcolade', 'Ecuador', 2010, '71%', 'Belgium', 3.5, '', 'Ecuador'),
#  (170,
#   'Bellflower',
#   'Kakao Kamili, Kilombero Valley',
#   2016,
#   '70%',
#   'U.S.A.',
#   3.5,
#   'Criollo, Trinitario',
#   'Tanzania'),
#  (171,
#   'Bellflower',
#   'Alto Beni, Palos Blanco',
#   2016,
#   '70%',
#   'U.S.A.',
#   3.25,
#   '',
#   'Bolivia'),
#  (172,
#   'Bellflower',
#   'Oko Caribe, Duarte P.',
#   2016,
#   '70%',
#   'U.S.A.',
#   3.5,
#   '',
#   'Domincan Republic'),
#  (173,
#   'Belyzium',
#   'Belize south, low fermentation',
#   2016,
#   '83%',
#   'Germany',
#   2.75,
#   'Trinitario',
#   'Belize'),
#  (174,
#   'Belyzium',
#   'Belize south',
#   2016,
#   '78%',
#   'Germany',
#   3.0,
#   'Trinitario',
#   'Belize'),
#  (175,
#   'Belyzium',
#   'Belize south',
#   2016,
#   '83%',
#   'Germany',
#   3.5,
#   'Trinitario',
#   'Belize'),
#  (176,
#   'Benoit Nihant',
#   'Baracoa',
#   2013,
#   '74%',
#   'Belgium',
#   3.5,
#   'Trinitario',
#   'Cuba'),
#  (177,
#   'Benoit Nihant',
#   'Chuao',
#   2013,
#   '74%',
#   'Belgium',
#   3.5,
#   'Criollo',
#   'Venezuela'),
#  (178,
#   'Benoit Nihant',
#   'Cuyagua Village',
#   2013,
#   '74%',
#   'Belgium',
#   3.5,
#   'Criollo',
#   'Venezuela'),
#  (179,
#   'Benoit Nihant',
#   'Rio Peripa H.',
#   2013,
#   '73%',
#   'Belgium',
#   4.0,
#   'Trinitario',
#   'Ecuador'),
#  (180,
#   'Benoit Nihant',
#   'Bali, Sukrama Bros. Farm, Melaya, 62hr C',
#   2011,
#   '72%',
#   'Belgium',
#   4.0,
#   'Trinitario',
#   'Indonesia'),
#  (181,
#   'Benoit Nihant',
#   'Somia Plantation, Sambirano, 70hr C',
#   2011,
#   '72%',
#   'Belgium',
#   3.75,
#   'Trinitario',
#   'Madagascar'),
#  (182, 'Bernachon', 'Nature', 2012, '55%', 'France', 2.75, '', ''),
#  (183,
#   'Beschle (Felchlin)',
#   'Madagascar',
#   2011,
#   '64%',
#   'Switzerland',
#   3.0,
#   'Trinitario',
#   'Madagascar'),
#  (184,
#   'Beschle (Felchlin)',
#   'Maracaibo',
#   2011,
#   '88%',
#   'Switzerland',
#   3.0,
#   'Criollo',
#   'Venezuela'),
#  (185,
#   'Beschle (Felchlin)',
#   'Indigena Amazonia, Grand Cru, Quizas',
#   2011,
#   '72%',
#   'Switzerland',
#   3.5,
#   '',
#   'Venezuela'),
#  (186,
#   'Beschle (Felchlin)',
#   'Ecuador',
#   2011,
#   '72%',
#   'Switzerland',
#   4.0,
#   '',
#   'Ecuador'),
#  (187,
#   'Beschle (Felchlin)',
#   'Carenero S., Barlovento, Grand Cru',
#   2010,
#   '70%',
#   'Switzerland',
#   3.25,
#   'Trinitario',
#   'Venezuela'),
#  (188,
#   'Beschle (Felchlin)',
#   'Porcelana, Premier Cru, Quizas No. 1',
#   2010,
#   '74%',
#   'Switzerland',
#   3.25,
#   'Criollo (Porcelana)',
#   'Venezuela'),
#  (189,
#   'Beschle (Felchlin)',
#   'Java, Grand Cru',
#   2010,
#   '64%',
#   'Switzerland',
#   3.5,
#   '',
#   'Indonesia'),
#  (190,
#   'Beschle (Felchlin)',
#   'Ocumare, Premier Cru, Quizas No. 2',
#   2010,
#   '72%',
#   'Switzerland',
#   3.5,
#   '',
#   'Venezuela'),
#  (191,
#   'Bisou',
#   'Nicaragua, American style',
#   2015,
#   '76%',
#   'U.S.A.',
#   2.5,
#   '',
#   'Nicaragua'),
#  (192,
#   'Bisou',
#   'San Andres, American style',
#   2015,
#   '76%',
#   'U.S.A.',
#   2.5,
#   '',
#   'Costa Rica'),
#  (193,
#   'Bisou',
#   'San Andres, silk',
#   2015,
#   '78%',
#   'U.S.A.',
#   2.5,
#   '',
#   'Costa Rica'),
#  (194, 'Bisou', 'Belize', 2015, '86%', 'U.S.A.', 3.25, 'Trinitario', 'Belize'),
#  (195,
#   'Bittersweet Origins',
#   'Ghana',
#   2012,
#   '72%',
#   'U.S.A.',
#   3.5,
#   'Forastero',
#   'Ghana'),
#  (196,
#   'Bittersweet Origins',
#   'Bali, Singaraja',
#   2010,
#   '75%',
#   'U.S.A.',
#   3.25,
#   '',
#   'Indonesia'),
#  (197,
#   'Bittersweet Origins',
#   '2009 Hapa Nibby',
#   2010,
#   '70%',
#   'U.S.A.',
#   3.75,
#   'Blend',
#   'Dominican Rep., Bali'),
#  (198,
#   'Bittersweet Origins',
#   'Bali, Singaraja',
#   2010,
#   '65%',
#   'U.S.A.',
#   2.75,
#   '',
#   'Indonesia'),
#  (199,
#   'Bittersweet Origins',
#   'Sambirano, 2009',
#   2010,
#   '70%',
#   'U.S.A.',
#   3.0,
#   'Trinitario',
#   'Madagascar'),
#  (200,
#   'Bittersweet Origins',
#   'Ocumare, prototype',
#   2010,
#   '78%',
#   'U.S.A.',
#   3.0,
#   'Criollo',
#   'Venezuela'),
#  (201,
#   'Bittersweet Origins',
#   'Puerto Plata',
#   2009,
#   '75%',
#   'U.S.A.',
#   3.0,
#   '',
#   'Dominican Republic'),
#  (202,
#   'Bittersweet Origins',
#   'Puerto Plata',
#   2009,
#   '65%',
#   'U.S.A.',
#   3.5,
#   '',
#   'Dominican Republic'),
#  (203,
#   'Bittersweet Origins',
#   'Sambirano',
#   2009,
#   '75%',
#   'U.S.A.',
#   3.25,
#   'Trinitario',
#   'Madagascar'),
#  (204,
#   'Bittersweet Origins',
#   'Sambirano',
#   2009,
#   '65%',
#   'U.S.A.',
#   3.5,
#   'Trinitario',
#   'Madagascar'),
#  (205,
#   'Bittersweet Origins',
#   'Sambirano',
#   2008,
#   '71%',
#   'U.S.A.',
#   3.0,
#   'Trinitario',
#   'Madagascar'),
#  (206,
#   'Bittersweet Origins',
#   'Bocas del Toro',
#   2008,
#   '75%',
#   'U.S.A.',
#   3.5,
#   '',
#   'Panama'),
#  (207,
#   'Bittersweet Origins',
#   'Puerto Plata',
#   2008,
#   '68%',
#   'U.S.A.',
#   3.75,
#   '',
#   'Dominican Republic'),
#  (208,
#   'Bittersweet Origins',
#   'Ankasa',
#   2008,
#   '70%',
#   'U.S.A.',
#   3.0,
#   'Forastero',
#   'Ghana'),
#  (209,
#   'Black Mountain',
#   'La Red',
#   2008,
#   '70%',
#   'U.S.A.',
#   2.75,
#   '',
#   'Dominican Republic'),
#  (210,
#   'Black Mountain',
#   'Carenero Superior',
#   2008,
#   '70%',
#   'U.S.A.',
#   2.75,
#   'Trinitario',
#   'Venezuela'),
#  (211,
#   'Black Mountain',
#   'Matiguas',
#   2008,
#   '70%',
#   'U.S.A.',
#   3.0,
#   '',
#   'Nicaragua'),
#  (212,
#   'Black River (A. Morin)',
#   'Blue Mountain Region',
#   2014,
#   '70%',
#   'U.K.',
#   2.75,
#   'Trinitario',
#   'Jamaica'),
#  (213,
#   'Blanxart',
#   'Congo, Grand Cru',
#   2013,
#   '82%',
#   'Spain',
#   3.5,
#   'Forastero',
#   'Congo'),
#  (214, 'Blanxart', 'Organic Dark', 2009, '72%', 'Spain', 2.75, '', ''),
#  (215,
#   'Blue Bandana',
#   "Akesson's E., Sambirano V.",
#   2016,
#   '82%',
#   'U.S.A.',
#   3.5,
#   'Trinitario',
#   'Madagascar'),
#  (216, 'Blue Bandana', 'Lachua', 2016, '75%', 'U.S.A.', 2.75, '', 'Guatemala'),
#  (217,
#   'Blue Bandana',
#   'Kokoa Kamili',
#   2016,
#   '75%',
#   'U.S.A.',
#   3.5,
#   '',
#   'Tanzania'),
#  (218,
#   'Blue Bandana',
#   'Zorzal Reserva',
#   2016,
#   '75%',
#   'U.S.A.',
#   3.0,
#   '',
#   'Dominican Republic'),
#  (219,
#   'Blue Bandana',
#   'Guatemala',
#   2012,
#   '70%',
#   'U.S.A.',
#   3.5,
#   '',
#   'Guatemala'),
#  (220,
#   'Blue Bandana',
#   'Madagascar',
#   2012,
#   '70%',
#   'U.S.A.',
#   3.75,
#   'Trinitario',
#   'Madagascar'),
#  (221, 'Bonnat', 'Selva Maya', 2016, '75%', 'France', 3.5, '', 'Mexico'),
#  (222, 'Bonnat', 'Kaori', 2014, '75%', 'France', 4.0, '', 'Brazil'),
#  (223,
#   'Bonnat',
#   'Los Colorados, Santo Domingo, Equateur',
#   2014,
#   '75%',
#   'France',
#   3.25,
#   '',
#   'Dominican Republic'),
#  (224,
#   'Bonnat',
#   'Surfin',
#   2014,
#   '65%',
#   'France',
#   3.75,
#   '',
#   'Venez,Africa,Brasil,Peru,Mex'),
#  (225, 'Bonnat', 'Maragnam', 2013, '75%', 'France', 3.5, '', 'Brazil'),
#  (226, 'Bonnat', 'Gabon', 2013, '75%', 'France', 3.25, '', 'Gabon'),
#  (227, 'Bonnat', 'Cuba', 2011, '75%', 'France', 3.5, 'Trinitario', 'Cuba'),
#  (228, 'Bonnat', 'Cusco, Cacao Cusco', 2011, '75%', 'France', 3.5, '', 'Peru'),
#  (229,
#   'Bonnat',
#   'Piura Blanco',
#   2011,
#   '75%',
#   'France',
#   3.5,
#   'Forastero (Nacional)',
#   'Peru'),
#  (230, 'Bonnat', 'Libanio', 2011, '75%', 'France', 3.75, '', 'Brazil'),
#  (231, 'Bonnat', 'Haiti', 2011, '75%', 'France', 4.0, '', 'Haiti'),
#  (232,
#   'Bonnat',
#   'Madagascar, 100% criollo',
#   2011,
#   '75%',
#   'France',
#   4.0,
#   'Criollo',
#   'Madagascar'),
#  (233, 'Bonnat', 'Juliana', 2011, '75%', 'France', 3.5, '', 'Brazil'),
#  (234,
#   'Bonnat',
#   'Jamaique',
#   2011,
#   '75%',
#   'France',
#   3.25,
#   'Trinitario',
#   'Jamaica'),
#  (235, 'Bonnat', 'Ivory Coast', 2009, '75%', 'France', 3.0, '', 'Ivory Coast'),
#  (236,
#   'Bonnat',
#   'Porcelana, Apotequil',
#   2009,
#   '75%',
#   'France',
#   2.75,
#   'Criollo',
#   'Peru'),
#  (237,
#   'Bonnat',
#   'Porcelana, Tabasco, Marfil de Blanco',
#   2009,
#   '75%',
#   'France',
#   3.0,
#   'Criollo',
#   'Mexico'),
#  (238,
#   'Bonnat',
#   'Xoconusco, cacao Real',
#   2009,
#   '75%',
#   'France',
#   3.0,
#   'Criollo',
#   'Mexico'),
#  (239,
#   'Bonnat',
#   'Porcelana, Venezuela',
#   2008,
#   '75%',
#   'France',
#   4.0,
#   'Criollo (Porcelana)',
#   'Venezuela'),
#  (240,
#   'Bonnat',
#   'Equateur',
#   2007,
#   '75%',
#   'France',
#   2.5,
#   'Forastero (Arriba)',
#   'Ecuador'),
#  (241,
#   'Bonnat',
#   'Trinite',
#   2006,
#   '75%',
#   'France',
#   3.75,
#   'Trinitario',
#   'Carribean'),
#  (242,
#   'Bonnat',
#   'Ocumare, Puerto Cabello',
#   2006,
#   '75%',
#   'France',
#   4.0,
#   '',
#   'Venezuela'),
#  (243,
#   'Bonnat',
#   'Maracaibo, El Rosario',
#   2006,
#   '75%',
#   'France',
#   4.0,
#   'Criollo',
#   'Venezuela'),
#  (244,
#   'Bonnat',
#   'Madagascar',
#   2006,
#   '75%',
#   'France',
#   4.0,
#   'Trinitario',
#   'Madagascar'),
#  (245, 'Bonnat', 'One Hundred', 2006, '100%', 'France', 1.5, '', ''),
#  (246, 'Bonnat', 'Ceylan', 2006, '75%', 'France', 3.0, '', 'Sri Lanka'),
#  (247,
#   'Bonnat',
#   'Chuao',
#   2006,
#   '75%',
#   'France',
#   4.0,
#   'Trinitario',
#   'Venezuela'),
#  (248,
#   'Bouga Cacao (Tulicorp)',
#   'El Oro, Hacienda de Oro',
#   2009,
#   '77%',
#   'Ecuador',
#   3.25,
#   'Forastero (Arriba)',
#   'Ecuador'),
#  (249,
#   'Bouga Cacao (Tulicorp)',
#   'El Oro, Hacienda de Oro',
#   2009,
#   '100%',
#   'Ecuador',
#   1.5,
#   'Forastero (Arriba)',
#   'Ecuador'),
#  (250,
#   'Bowler Man',
#   'Maya Mountain',
#   2014,
#   '70%',
#   'U.S.A.',
#   2.75,
#   'Trinitario',
#   'Belize'),
#  (251,
#   'Bowler Man',
#   'Conacado',
#   2014,
#   '70%',
#   'U.S.A.',
#   2.75,
#   '',
#   'Dominican Republic'),
#  (252,
#   "Brasstown aka It's Chocolate",
#   'Guasare, Zulia Prov.',
#   2016,
#   '70%',
#   'U.S.A.',
#   3.5,
#   'Criollo',
#   'Venezuela'),
#  (253,
#   "Brasstown aka It's Chocolate",
#   "O'payo, Waslala",
#   2016,
#   '70%',
#   'U.S.A.',
#   3.75,
#   '',
#   'Nicaragua'),
#  (254,
#   "Brasstown aka It's Chocolate",
#   'Conacado',
#   2015,
#   '68%',
#   'U.S.A.',
#   3.75,
#   '',
#   'Dominican Republic'),
#  (255,
#   "Brasstown aka It's Chocolate",
#   'Maya Mountain',
#   2014,
#   '70%',
#   'U.S.A.',
#   3.75,
#   'Trinitario',
#   'Belize'),
#  (256,
#   "Brasstown aka It's Chocolate",
#   'Chuao',
#   2014,
#   '70%',
#   'U.S.A.',
#   4.0,
#   'Trinitario',
#   'Venezuela'),
#  (257,
#   "Brasstown aka It's Chocolate",
#   'Cooproagro',
#   2013,
#   '72%',
#   'U.S.A.',
#   3.0,
#   'Trinitario',
#   'Dominican Republic'),
#  (258,
#   "Brasstown aka It's Chocolate",
#   'Camino Verde, Guayas',
#   2013,
#   '70%',
#   'U.S.A.',
#   3.25,
#   '',
#   'Ecuador'),
#  (259,
#   "Brasstown aka It's Chocolate",
#   'Ghana',
#   2013,
#   '75%',
#   'U.S.A.',
#   3.5,
#   'Forastero',
#   'Ghana'),
#  (260,
#   "Brasstown aka It's Chocolate",
#   'Chuao, Mantuano blend',
#   2013,
#   '85%',
#   'U.S.A.',
#   3.5,
#   'Trinitario',
#   'Venezuela'),
#  (261,
#   'Brazen',
#   'Elvesia P.',
#   2015,
#   '60%',
#   'U.S.A.',
#   3.0,
#   '',
#   'Dominican Republic'),
#  (262,
#   'Brazen',
#   'Elvesia P.',
#   2015,
#   '80%',
#   'U.S.A.',
#   3.25,
#   '',
#   'Dominican Republic'),
#  (263,
#   'Brazen',
#   'Alta Verapaz, 2014',
#   2015,
#   '70%',
#   'U.S.A.',
#   3.5,
#   '',
#   'Guatemala'),
#  (264,
#   'Brazen',
#   'Ambolikapiky P.',
#   2015,
#   '80%',
#   'U.S.A.',
#   2.75,
#   '',
#   'Madagascar'),
#  (265,
#   'Brazen',
#   'Maya Mountain',
#   2015,
#   '80%',
#   'U.S.A.',
#   3.25,
#   'Trinitario',
#   'Belize'),
#  (266,
#   'Brazen',
#   'Ambolikapkly P.',
#   2015,
#   '60%',
#   'U.S.A.',
#   3.25,
#   '',
#   'Madagascar'),
#  (267,
#   'Breeze Mill',
#   'Jamaica',
#   2013,
#   '70%',
#   'U.S.A.',
#   3.0,
#   'Trinitario',
#   'Jamaica'),
#  (268,
#   'Bright',
#   'Somia Plantation',
#   2014,
#   '72%',
#   'Australia',
#   3.0,
#   'Trinitario',
#   'Madagascar'),
#  (269,
#   'Bright',
#   'Marabel Farms',
#   2014,
#   '70%',
#   'Australia',
#   3.5,
#   '',
#   'Dominican Republic'),
#  (270,
#   'Bright',
#   'Camino Verde, Balao, Guayas',
#   2014,
#   '72%',
#   'Australia',
#   3.5,
#   '',
#   'Ecuador'),
#  (271,
#   'Bright',
#   'Gran Couva',
#   2014,
#   '68%',
#   'Australia',
#   2.75,
#   'Trinitario',
#   'Trinidad'),
#  (272, 'Britarev', 'Ecuador', 2015, '70%', 'Russia', 3.25, '', 'Ecuador'),
#  (273,
#   'Bronx Grrl Chocolate',
#   'Dominican Republic',
#   2013,
#   '68%',
#   'U.S.A.',
#   2.75,
#   '',
#   'Dominican Republic'),
#  (274,
#   'Burnt Fork Bend',
#   'Trinidad',
#   2014,
#   '72%',
#   'U.S.A.',
#   3.25,
#   'Trinitario',
#   'Trinidad'),
#  (275, 'Burnt Fork Bend', 'Mindo', 2014, '72%', 'U.S.A.', 3.5, '', 'Ecuador'),
#  (276,
#   'Burnt Fork Bend',
#   'Belize',
#   2014,
#   '72%',
#   'U.S.A.',
#   3.25,
#   'Trinitario',
#   'Belize'),
#  (277, 'Burnt Fork Bend', 'Blend', 2014, '72%', 'U.S.A.', 3.25, 'Blend', ''),
#  (278,
#   'Burnt Fork Bend',
#   'Ecuador, Bob Bar',
#   2014,
#   '60%',
#   'U.S.A.',
#   2.5,
#   '',
#   'Ecuador'),
#  (279,
#   'Cacao Arabuco',
#   'Puerto Rico',
#   2015,
#   '70%',
#   'Puerto Rico',
#   2.5,
#   '',
#   'Puerto Rico'),
#  (280,
#   'Cacao Atlanta',
#   'Tumbes',
#   2014,
#   '75%',
#   'U.S.A.',
#   2.5,
#   'Criollo',
#   'Peru'),
#  (281,
#   'Cacao Atlanta',
#   'Dominican Republic, "Love Bar"',
#   2010,
#   '75%',
#   'U.S.A.',
#   2.5,
#   '',
#   'Dominican Republic'),
#  (282,
#   'Cacao Atlanta',
#   'Dominican Republic w/ nibs',
#   2010,
#   '75%',
#   'U.S.A.',
#   2.75,
#   '',
#   'Dominican Republic'),
#  (283,
#   'Cacao Atlanta',
#   'Patanemo',
#   2010,
#   '75%',
#   'U.S.A.',
#   2.25,
#   '',
#   'Venezuela'),
#  (284,
#   'Cacao Barry',
#   "Grand 'Anse",
#   2016,
#   '65%',
#   'France',
#   3.5,
#   'Trinitario, Criollo',
#   'Haiti'),
#  (285,
#   'Cacao Barry',
#   'Santo Domingo',
#   2010,
#   '70%',
#   'France',
#   3.0,
#   '',
#   'Dominican Republic'),
#  (286, 'Cacao Barry', 'Tanzania', 2008, '75%', 'France', 2.0, '', 'Tanzania'),
#  (287,
#   'Cacao Barry',
#   'Venezuela',
#   2007,
#   '72%',
#   'France',
#   2.0,
#   '',
#   'Venezuela'),
#  (288, 'Cacao Barry', 'Mexico', 2007, '66%', 'France', 3.0, '', 'Mexico'),
#  (289,
#   'Cacao de Origen',
#   'Chuao',
#   2015,
#   '77%',
#   'Venezuela',
#   3.5,
#   'Trinitario',
#   'Venezuela'),
#  (290,
#   'Cacao de Origen',
#   'Rio Caribe',
#   2015,
#   '75%',
#   'Venezuela',
#   3.25,
#   'Trinitario',
#   'Venezuela'),
#  (291,
#   'Cacao de Origen',
#   'Agua Fria; Sucre region',
#   2014,
#   '75%',
#   'Venezuela',
#   2.5,
#   '',
#   'Venezuela'),
#  (292,
#   'Cacao de Origen',
#   'Macuare; Miranda; Chloe formula',
#   2014,
#   '74%',
#   'Venezuela',
#   3.25,
#   '',
#   'Venezuela'),
#  (293,
#   'Cacao de Origen',
#   'Chuao, Aragua region',
#   2014,
#   '75%',
#   'Venezuela',
#   3.5,
#   'Trinitario',
#   'Venezuela'),
#  (294,
#   'Cacao de Origen',
#   'Chuao, Aragua region',
#   2014,
#   '70%',
#   'Venezuela',
#   3.75,
#   'Trinitario',
#   'Venezuela'),
#  (295,
#   'Cacao de Origin',
#   'Hacienda la Trinidad',
#   2015,
#   '74%',
#   'Venezuela',
#   3.25,
#   '',
#   'Venezuela'),
#  (296,
#   'Cacao Hunters',
#   'Macondo',
#   2016,
#   '71%',
#   'Colombia',
#   3.75,
#   '',
#   'Colombia'),
#  (297,
#   'Cacao Hunters',
#   'Perla Negra',
#   2016,
#   '74%',
#   'Colombia',
#   3.75,
#   '',
#   'Colombia'),
#  (298,
#   'Cacao Hunters',
#   'Arhuacos',
#   2015,
#   '72%',
#   'Colombia',
#   3.75,
#   '',
#   'Colombia'),
#  (299,
#   'Cacao Hunters',
#   'Sierra Nevada',
#   2014,
#   '64%',
#   'Colombia',
#   3.5,
#   '',
#   'Colombia'),
#  (300,
#   'Cacao Hunters',
#   'Tumaco',
#   2014,
#   '70%',
#   'Colombia',
#   3.5,
#   '',
#   'Colombia'),
#  (301,
#   'Cacao Hunters',
#   'Boyaca, Aprocampa Coop, Pauna',
#   2014,
#   '69%',
#   'Colombia',
#   2.75,
#   '',
#   'Colombia'),
#  (302,
#   'Cacao Hunters',
#   'Arauca',
#   2014,
#   '70%',
#   'Colombia',
#   3.25,
#   '',
#   'Colombia'),
#  (303,
#   'Cacao Market',
#   'Jutiapa, lot 050916D',
#   2016,
#   '70%',
#   'U.S.A.',
#   3.5,
#   'Trinitario',
#   'Honduras'),
#  (304,
#   'Cacao Prieto',
#   'Criollo, Dominican Republic',
#   2012,
#   '72%',
#   'U.S.A.',
#   3.75,
#   'Criollo',
#   'Dominican Republic'),
#  (305,
#   'Cacao Prieto',
#   'Dominican Republicm, rustic',
#   2011,
#   '72%',
#   'U.S.A.',
#   3.0,
#   '',
#   'Dominican Republic'),
#  (306,
#   'Cacao Prieto',
#   'Dominican Republic',
#   2011,
#   '66%',
#   'U.S.A.',
#   3.75,
#   '',
#   'Dominican Republic'),
#  (307,
#   'Cacao Prieto',
#   'Dominican Republic, rustic',
#   2011,
#   '65%',
#   'U.S.A.',
#   3.25,
#   '',
#   'Dominican Republic'),
#  (308,
#   'Cacao Sampaka',
#   'Mahali, Kasai',
#   2016,
#   '70%',
#   'Spain',
#   3.5,
#   'Criollo',
#   'Congo'),
#  (309,
#   'Cacao Sampaka',
#   'Madagascar',
#   2010,
#   '71%',
#   'Spain',
#   3.5,
#   'Trinitario',
#   'Madagascar'),
#  (310, 'Cacao Sampaka', 'Ecuador', 2010, '71%', 'Spain', 3.75, '', 'Ecuador'),
#  (311,
#   'Cacao Sampaka',
#   'Papua',
#   2010,
#   '71%',
#   'Spain',
#   4.0,
#   '',
#   'Papua New Guinea'),
#  (312,
#   'Cacao Sampaka',
#   'Grenada',
#   2010,
#   '71%',
#   'Spain',
#   3.25,
#   'Trinitario',
#   'Grenada'),
#  (313,
#   'Cacao Sampaka',
#   'Venezuela',
#   2010,
#   '71%',
#   'Spain',
#   3.5,
#   '',
#   'Venezuela'),
#  (314,
#   'Cacao Sampaka',
#   'Venezuela',
#   2010,
#   '77%',
#   'Spain',
#   3.5,
#   '',
#   'Venezuela'),
#  (315,
#   'Cacao Sampaka',
#   'Porcelana, Tabasco, La Joya',
#   2009,
#   '70%',
#   'Spain',
#   4.0,
#   'Criollo',
#   'Mexico'),
#  (316,
#   'Cacao Sampaka',
#   'Xoconusco, Chiapas',
#   2009,
#   '70%',
#   'Spain',
#   4.0,
#   'Criollo',
#   'Mexico'),
#  (317,
#   'Cacao Store',
#   'Madagascar',
#   2015,
#   '70%',
#   'Japan',
#   3.0,
#   'Trinitario',
#   'Madagascar'),
#  (318, 'Cacao Store', 'Peru', 2015, '70%', 'Japan', 3.25, '', 'Peru'),
#  (319,
#   'Cacao Store',
#   'Vietnam',
#   2015,
#   '70%',
#   'Japan',
#   3.5,
#   'Trinitario',
#   'Vietnam'),
#  (320,
#   'Cacaosuyo (Theobroma Inversiones)',
#   'Piura',
#   2013,
#   '70%',
#   'Peru',
#   3.25,
#   '',
#   'Peru'),
#  (321,
#   'Cacaoyere (Ecuatoriana)',
#   'Amazonia',
#   2008,
#   '63%',
#   'Ecuador',
#   3.5,
#   'Forastero (Arriba)',
#   'Ecuador'),
#  (322,
#   'Cacaoyere (Ecuatoriana)',
#   'Esmeraldas',
#   2008,
#   '71%',
#   'Ecuador',
#   3.5,
#   'Forastero (Arriba)',
#   'Ecuador'),
#  (323,
#   'Cacaoyere (Ecuatoriana)',
#   'Bolivar',
#   2008,
#   '82%',
#   'Ecuador',
#   2.5,
#   'Forastero (Arriba)',
#   'Ecuador'),
#  (324,
#   'Cacaoyere (Ecuatoriana)',
#   'Pichincha',
#   2008,
#   '91%',
#   'Ecuador',
#   1.5,
#   'Forastero (Arriba)',
#   'Ecuador'),
#  (325,
#   'Callebaut',
#   'Grenade',
#   2008,
#   '60%',
#   'Belgium',
#   2.75,
#   'Trinitario',
#   'Grenada'),
#  (326, 'Callebaut', 'Baking', 2007, '70%', 'Belgium', 1.0, '', 'Ecuador'),
#  (327, 'C-Amaro', 'Cuba', 2014, '75%', 'Italy', 2.5, '', 'Cuba'),
#  (328,
#   'C-Amaro',
#   'Dominican Republic',
#   2014,
#   '72%',
#   'Italy',
#   3.0,
#   '',
#   'Dominican Republic'),
#  (329, 'C-Amaro', 'Lago di Como, Blu', 2014, '70%', 'Italy', 3.5, 'Blend', ''),
#  (330, 'C-Amaro', 'Ecuador', 2013, '100%', 'Italy', 3.5, '', 'Ecuador'),
#  (331, 'C-Amaro', 'Venezuela', 2012, '80%', 'Italy', 3.0, '', 'Venezuela'),
#  (332,
#   'C-Amaro',
#   'Sao Tome',
#   2011,
#   '78%',
#   'Italy',
#   2.25,
#   'Forastero',
#   'Sao Tome'),
#  (333,
#   'C-Amaro',
#   'Trinidad',
#   2011,
#   '70%',
#   'Italy',
#   2.5,
#   'Trinitario',
#   'Trinidad'),
#  (334, 'Cao', 'Porcelana', 2016, '75%', 'U.S.A.', 2.5, 'Criollo', 'Venezuela'),
#  (335, 'Cao', 'Tanzania', 2016, '73%', 'U.S.A.', 2.75, '', 'Tanzania'),
#  (336,
#   'Cao',
#   'Porcelana, Batch 5163',
#   2016,
#   '70%',
#   'U.S.A.',
#   3.0,
#   'Criollo',
#   'Venezuela'),
#  (337, 'Cao', 'Bolivia', 2016, '75%', 'U.S.A.', 3.0, '', 'Bolivia'),
#  (338, 'Cao', 'Brazil', 2016, '70%', 'U.S.A.', 3.25, 'Trinitario', 'Brazil'),
#  (339,
#   'Caoni (Tulicorp)',
#   'Esmeraldas',
#   2008,
#   '77%',
#   'Ecuador',
#   2.0,
#   'Forastero (Arriba)',
#   'Ecuador'),
#  (340,
#   'Caoni (Tulicorp)',
#   'Manabi',
#   2008,
#   '77%',
#   'Ecuador',
#   2.5,
#   'Forastero (Arriba)',
#   'Ecuador'),
#  (341,
#   'Caoni (Tulicorp)',
#   'Los Rios',
#   2008,
#   '77%',
#   'Ecuador',
#   2.75,
#   'Forastero (Arriba)',
#   'Ecuador'),
#  (342,
#   'Caoni (Tulicorp)',
#   'Manabi',
#   2008,
#   '55%',
#   'Ecuador',
#   3.0,
#   'Forastero (Arriba)',
#   'Ecuador'),
#  (343,
#   'Caoni (Tulicorp)',
#   'Los Rios',
#   2008,
#   '55%',
#   'Ecuador',
#   3.25,
#   'Forastero (Arriba)',
#   'Ecuador'),
#  (344,
#   'Caoni (Tulicorp)',
#   'Esmeraldas',
#   2008,
#   '55%',
#   'Ecuador',
#   3.5,
#   'Forastero (Arriba)',
#   'Ecuador'),
#  (345,
#   'Captain Pembleton',
#   'Saidor Estate, Madang P.',
#   2014,
#   '70%',
#   'New Zealand',
#   3.5,
#   'Trinitario',
#   'Papua New Guinea'),
#  (346,
#   'Captain Pembleton',
#   'Kulili Estate',
#   2014,
#   '70%',
#   'New Zealand',
#   3.75,
#   '',
#   'Papua New Guinea'),
#  (347,
#   'Caribeans',
#   'Antigua, Special Reserve',
#   2015,
#   '72%',
#   'Costa Rica',
#   3.5,
#   '',
#   'Guatemala'),
#  (348,
#   'Caribeans',
#   'Talamanca, Raul-Kekoldo community',
#   2015,
#   '72%',
#   'Costa Rica',
#   3.25,
#   '',
#   'Costa Rica'),
#  (349,
#   'Caribeans',
#   'Anselmo Paraiso Estate',
#   2015,
#   '72%',
#   'Costa Rica',
#   3.5,
#   '',
#   'Costa Rica'),
#  (350,
#   'Caribeans',
#   'Costa Rica',
#   2012,
#   '72%',
#   'Costa Rica',
#   3.0,
#   'Forastero',
#   'Costa Rica'),
#  (351,
#   'Caribeans',
#   'Costa Rica',
#   2012,
#   '80%',
#   'Costa Rica',
#   2.75,
#   'Forastero',
#   'Costa Rica'),
#  (352,
#   'Carlotta Chocolat',
#   'Arauca',
#   2016,
#   '65%',
#   'Colombia',
#   3.0,
#   'Trinitario',
#   'Colombia'),
#  (353,
#   'Carlotta Chocolat',
#   'Tumaco',
#   2016,
#   '65%',
#   'Colombia',
#   3.25,
#   'Trinitario',
#   'Colombia'),
#  (354,
#   'Carlotta Chocolat',
#   'Cordoba',
#   2016,
#   '65%',
#   'Colombia',
#   3.25,
#   'Trinitario',
#   'Colombia'),
#  (355,
#   'Carlotta Chocolat',
#   'Huila',
#   2016,
#   '65%',
#   'Colombia',
#   3.5,
#   'Trinitario',
#   'Colombia'),
#  (356,
#   'Carlotta Chocolat',
#   'Cesar',
#   2016,
#   '65%',
#   'Colombia',
#   3.5,
#   'CCN51',
#   'Colombia'),
#  (357,
#   'Castronovo',
#   'Maya Mtn, Batch 454, Heirloom',
#   2016,
#   '72%',
#   'U.S.A.',
#   4.0,
#   'Trinitario',
#   'Belize'),
#  (358,
#   'Castronovo',
#   'the lost city, gracias a dias, batch 362',
#   2015,
#   '72%',
#   'U.S.A.',
#   3.5,
#   'Trinitario',
#   'Honduras'),
#  (359,
#   'Castronovo',
#   'Duarte, Batch 360',
#   2015,
#   '70%',
#   'U.S.A.',
#   3.75,
#   'Criollo, Trinitario',
#   'Domincan Republic'),
#  (360,
#   'Castronovo',
#   'Piaroa, Amazonas, Batch 350',
#   2015,
#   '72%',
#   'U.S.A.',
#   3.5,
#   '',
#   'Venezuela'),
#  (361,
#   'Castronovo',
#   'Sierra Nevada',
#   2014,
#   '72%',
#   'U.S.A.',
#   3.5,
#   'Criollo, Trinitario',
#   'Colombia'),
#  (362,
#   'Castronovo',
#   'Arauca',
#   2014,
#   '76%',
#   'U.S.A.',
#   3.5,
#   'Criollo, Trinitario',
#   'Colombia'),
#  (363,
#   'Castronovo',
#   'Elvesia P.',
#   2014,
#   '70%',
#   'U.S.A.',
#   2.75,
#   'Trinitario',
#   'Dominican Republic'),
#  (364,
#   'Castronovo',
#   'Bolivia',
#   2013,
#   '70%',
#   'U.S.A.',
#   3.0,
#   'Trinitario',
#   'Bolivia'),
#  (365,
#   'Castronovo',
#   'Conacado',
#   2013,
#   '73%',
#   'U.S.A.',
#   3.5,
#   'Trinitario',
#   'Dominican Republic'),
#  (366,
#   'Castronovo',
#   'San Martin',
#   2013,
#   '70%',
#   'U.S.A.',
#   2.5,
#   'Criollo',
#   'Peru'),
#  (367,
#   'Castronovo',
#   'Guaniamo, Amazonas',
#   2013,
#   '70%',
#   'U.S.A.',
#   3.25,
#   '',
#   'Venezuela'),
#  (368,
#   'Castronovo',
#   'Nicaragua',
#   2013,
#   '72%',
#   'U.S.A.',
#   3.25,
#   'Trinitario',
#   'Nicaragua'),
#  (369, 'Castronovo', 'Tumbes', 2013, '70%', 'U.S.A.', 2.75, 'Criollo', 'Peru'),
#  (370, 'Castronovo', 'Guaniamo', 2013, '72%', 'U.S.A.', 3.0, '', 'Venezuela'),
#  (371, 'Cello', 'Ecuador', 2014, '70%', 'U.S.A.', 2.5, '', 'Ecuador'),
#  (372, 'Cello', 'Peru', 2014, '70%', 'U.S.A.', 2.75, '', 'Peru'),
#  (373, 'Cello', 'Venezuela', 2014, '70%', 'U.S.A.', 2.75, '', 'Venezuela'),
#  (374, 'Cello', 'Bolivia', 2014, '70%', 'U.S.A.', 3.0, '', 'Bolivia'),
#  (375, 'Cemoi', 'Equateur', 2009, '72%', 'France', 2.75, '', 'Ecuador'),
#  (376,
#   'Chaleur B',
#   'Uganda',
#   2014,
#   '70%',
#   'Canada',
#   2.75,
#   'Forastero',
#   'Uganda'),
#  (377, 'Charm School', 'Maya Mtn', 2016, '70%', 'U.S.A.', 3.25, '', 'Belize'),
#  (378,
#   'Chchukululu (Tulicorp)',
#   'Arriba',
#   2010,
#   '55%',
#   'Ecuador',
#   2.75,
#   'Forastero (Arriba)',
#   'Ecuador'),
#  (379,
#   'Chchukululu (Tulicorp)',
#   'Los Rios',
#   2008,
#   '75%',
#   'Ecuador',
#   3.0,
#   'Forastero (Arriba)',
#   'Ecuador'),
#  (380,
#   'Chequessett',
#   'la Amistad',
#   2014,
#   '70%',
#   'U.S.A.',
#   3.5,
#   '',
#   'Costa Rica'),
#  (381, 'Chloe Chocolat', 'Blend No. 1', 2011, '70%', 'France', 3.5, '', ''),
#  (382, 'Chocablog', 'Ecuador', 2015, '70%', 'U.K.', 3.25, '', 'Ecuador'),
#  (383,
#   'Choco Del Sol',
#   'Maya Mountain w/ nibs',
#   2014,
#   '75%',
#   'Germany',
#   3.0,
#   'Trinitario',
#   'Belize'),
#  (384,
#   'Choco Del Sol',
#   'Maya Mountain',
#   2014,
#   '82%',
#   'Germany',
#   3.25,
#   'Trinitario',
#   'Belize'),
#  (385,
#   'Choco Dong',
#   'Mekong Delta, early 2014 Harvest',
#   2015,
#   '70%',
#   'South Korea',
#   2.75,
#   'Trinitario',
#   'Vietnam'),
#  (386,
#   'Choco Dong',
#   'Tawau, Oct. 2015 Harvest',
#   2015,
#   '70%',
#   'South Korea',
#   3.5,
#   'Trinitario',
#   'Malaysia'),
#  (387, 'Chocolarder', 'Peru', 2015, '65%', 'U.K.', 2.5, 'Criollo', 'Peru'),
#  (388,
#   'Chocolarder',
#   'Peru + nibs',
#   2015,
#   '65%',
#   'U.K.',
#   2.75,
#   'Criollo',
#   'Peru'),
#  (389,
#   'Chocolarder',
#   'Dominican Republic',
#   2015,
#   '80%',
#   'U.K.',
#   2.5,
#   '',
#   'Dominican Republic'),
#  (390,
#   "Chocola'te",
#   'Madagascar',
#   2011,
#   '70%',
#   'U.S.A.',
#   3.75,
#   'Trinitario',
#   'Madagascar'),
#  (391,
#   "Chocola'te",
#   'Venezuela',
#   2011,
#   '68%',
#   'U.S.A.',
#   3.75,
#   '',
#   'Venezuela'),
#  (392,
#   'Chocolate Alchemist-Philly',
#   'Tumbes, "Zarumilla"',
#   2016,
#   '90%',
#   'U.S.A.',
#   2.5,
#   '',
#   'Peru'),
#  (393,
#   'Chocolate Alchemist-Philly',
#   'Philly Blend, 5 plantations',
#   2016,
#   '80%',
#   'U.S.A.',
#   2.5,
#   '',
#   ''),
#  (394,
#   'Chocolate Con Amor',
#   'Wild Bolivian',
#   2016,
#   '70%',
#   'U.S.A.',
#   2.5,
#   '',
#   'Bolivia'),
#  (395,
#   'Chocolate Con Amor',
#   'Uganda',
#   2016,
#   '70%',
#   'U.S.A.',
#   2.75,
#   '',
#   'Uganda'),
#  (396,
#   'Chocolate Con Amor',
#   'Dominican Republic',
#   2016,
#   '60%',
#   'U.S.A.',
#   3.0,
#   '',
#   'Dominican Republic'),
#  (397,
#   'Chocolate Con Amor',
#   'Dominican Republic',
#   2016,
#   '75%',
#   'U.S.A.',
#   3.0,
#   '',
#   'Dominican Republic'),
#  (398,
#   'Chocolate Con Amor',
#   'Ocumare',
#   2016,
#   '80%',
#   'U.S.A.',
#   3.0,
#   'Criollo (Ocumare)',
#   'Venezuela'),
#  (399,
#   'Chocolate Con Amor',
#   'Ecuador',
#   2016,
#   '70%',
#   'U.S.A.',
#   3.25,
#   '',
#   'Ecuador'),
#  (400,
#   'Chocolate Con Amor',
#   'Nicaragua',
#   2016,
#   '80%',
#   'U.S.A.',
#   2.75,
#   '',
#   'Nicaragua'),
#  (401,
#   'Chocolate Conspiracy',
#   'Peru',
#   2014,
#   '74%',
#   'U.S.A.',
#   2.75,
#   '',
#   'Peru'),
#  (402,
#   'Chocolate Makers',
#   'Tres Hombres',
#   2015,
#   '75%',
#   'Amsterdam',
#   3.25,
#   'Trinitario',
#   'Dominican Republic'),
#  (403,
#   'Chocolate Makers',
#   'Congo, Gorilla bar',
#   2015,
#   '68%',
#   'Amsterdam',
#   3.5,
#   'Forastero',
#   'Congo'),
#  (404,
#   'Chocolate Makers',
#   'Peru, Awagum bar',
#   2015,
#   '80%',
#   'Amsterdam',
#   3.75,
#   'Criollo',
#   'Peru'),
#  (405,
#   'Chocolate Tree, The',
#   'Maranon',
#   2015,
#   '69%',
#   'Scotland',
#   3.75,
#   'Forastero (Nacional)',
#   'Peru'),
#  (406,
#   'Chocolate Tree, The',
#   'Carenero Superior',
#   2015,
#   '80%',
#   'Scotland',
#   3.75,
#   'Trinitario',
#   'Venezuela'),
#  (407,
#   'Chocolate Tree, The',
#   'Peru',
#   2013,
#   '70%',
#   'Scotland',
#   3.75,
#   'Forastero (Nacional)',
#   'Peru'),
#  (408,
#   'Chocolate Tree, The',
#   'Ecuador',
#   2012,
#   '82%',
#   'Scotland',
#   2.5,
#   'Forastero (Arriba)',
#   'Ecuador'),
#  (409,
#   'Chocolate Tree, The',
#   'Peru',
#   2012,
#   '68%',
#   'Scotland',
#   2.75,
#   'Criollo',
#   'Peru'),
#  (410,
#   'Chocolate Tree, The',
#   'Madagascar',
#   2012,
#   '72%',
#   'Scotland',
#   3.25,
#   'Criollo',
#   'Madagascar'),
#  (411,
#   'Chocolats Privilege',
#   'Xoconusco',
#   2014,
#   '70%',
#   'Canada',
#   2.5,
#   'Criollo',
#   'Mexico'),
#  (412,
#   'ChocoReko',
#   'Patanemo',
#   2015,
#   '77%',
#   'Japan',
#   3.0,
#   'Criollo',
#   'Venezuela'),
#  (413,
#   'Chocosol',
#   'Chiapas, Lacandon Jungle, Oaxacom Mtn',
#   2011,
#   '65%',
#   'Canada',
#   3.25,
#   '',
#   'Mexico'),
#  (414,
#   'Chocovic',
#   'Xoconusco',
#   2010,
#   '71%',
#   'Spain',
#   3.25,
#   'Criollo',
#   'Mexico'),
#  (415,
#   'Chocovic',
#   'Sambirano',
#   2010,
#   '71%',
#   'Spain',
#   3.5,
#   'Trinitario',
#   'Madagascar'),
#  (416, 'Chocovic', 'Kendari', 2009, '60%', 'Spain', 3.25, '', ''),
#  (417, 'Chocovic', 'Tarakan', 2009, '75%', 'Spain', 3.25, '', ''),
#  (418,
#   'Chocovic',
#   'Ocumare',
#   2008,
#   '71%',
#   'Spain',
#   3.5,
#   'Criollo',
#   'Venezuela'),
#  (419,
#   'Chocovic',
#   'Bolivar, Guaranda',
#   2007,
#   '71%',
#   'Spain',
#   2.5,
#   'Forastero (Arriba)',
#   'Ecuador'),
#  (420,
#   'Chocovic',
#   'Guyave',
#   2007,
#   '71%',
#   'Spain',
#   2.5,
#   'Trinitario',
#   'Grenada'),
#  (421, 'Chocovic', 'Maragda', 2007, '70%', 'Spain', 3.0, 'Blend', ''),
#  (422,
#   'Chocovivo',
#   'Tabasco',
#   2015,
#   '65%',
#   'U.S.A.',
#   2.5,
#   'Trinitario',
#   'Mexico'),
#  (423,
#   'Chocovivo',
#   'Tabasco',
#   2015,
#   '75%',
#   'U.S.A.',
#   2.5,
#   'Trinitario',
#   'Mexico'),
#  (424,
#   'Choklat',
#   'Ocumare',
#   2009,
#   '80%',
#   'Canada',
#   2.5,
#   'Criollo',
#   'Venezuela'),
#  (425,
#   'Choklat',
#   'Porcelana, Tabasco',
#   2009,
#   '70%',
#   'Canada',
#   2.75,
#   'Criollo',
#   'Mexico'),
#  (426, 'Choklat', 'Brazilian', 2009, '70%', 'Canada', 3.0, '', 'Brazil'),
#  (427, 'Choklat', 'Brazilian', 2009, '80%', 'Canada', 3.0, '', 'Brazil'),
#  (428,
#   'Choklat',
#   'Ocumare',
#   2009,
#   '70%',
#   'Canada',
#   3.0,
#   'Criollo',
#   'Venezuela'),
#  (429,
#   'Chokolat Elot (Girard)',
#   'Guadeloupe',
#   2013,
#   '42%',
#   'Martinique',
#   2.75,
#   '',
#   'Martinique'),
#  (430,
#   'Choocsol',
#   'Chiapas, Lacandon Jungle, Oaxacom Mtn',
#   2016,
#   '75%',
#   'Canada',
#   3.25,
#   '',
#   'Mexico'),
#  (431,
#   'Christopher Morel (Felchlin)',
#   'Maranon Canyon, Fortunato No. 4',
#   2011,
#   '68%',
#   'Canada',
#   3.75,
#   'Forastero (Nacional)',
#   'Peru'),
#  (432,
#   'Chuao Chocolatier',
#   'Choroni',
#   2009,
#   '61%',
#   'U.S.A.',
#   3.0,
#   'Criollo',
#   'Venezuela'),
#  (433,
#   'Chuao Chocolatier (Pralus)',
#   'Chuao',
#   2010,
#   '77%',
#   'U.S.A.',
#   2.75,
#   'Trinitario',
#   'Venezuela'),
#  (434,
#   'Claudio Corallo',
#   'Terreiro Velho P.',
#   2010,
#   '73.50%',
#   'Sao Tome',
#   3.75,
#   'Forastero',
#   'Sao Tome & Principe'),
#  (435,
#   'Claudio Corallo',
#   'Terreiro Velho P. w/ sugar crystals',
#   2008,
#   '80%',
#   'Sao Tome',
#   3.0,
#   'Forastero',
#   'Sao Tome & Principe'),
#  (436,
#   'Claudio Corallo',
#   'Terreiro Velho P.',
#   2008,
#   '75%',
#   'Sao Tome',
#   4.0,
#   'Forastero',
#   'Sao Tome & Principe'),
#  (437,
#   'Claudio Corallo',
#   'Principe',
#   2008,
#   '100%',
#   'Sao Tome',
#   1.0,
#   'Forastero',
#   'Sao Tome & Principe'),
#  (438,
#   'Cloudforest',
#   'Camino Verde P., Balao, Guayas, 2014',
#   2015,
#   '73%',
#   'U.S.A.',
#   3.5,
#   '',
#   'Ecuador'),
#  (439,
#   'Coleman & Davis',
#   'Sambirano',
#   2015,
#   '75%',
#   'U.S.A.',
#   3.0,
#   'Trinitario',
#   'Madagascar'),
#  (440,
#   'Compania de Chocolate (Salgado)',
#   'Sur del Lago',
#   2010,
#   '70%',
#   'Argentina',
#   3.25,
#   '',
#   'Venezuela'),
#  (441,
#   'Compania de Chocolate (Salgado)',
#   'Carenero Superior',
#   2008,
#   '80%',
#   'Argentina',
#   2.75,
#   'Trinitario',
#   'Venezuela'),
#  (442,
#   'Compania de Chocolate (Salgado)',
#   'Moxos',
#   2008,
#   '72%',
#   'Argentina',
#   3.25,
#   '',
#   'Bolivia'),
#  (443,
#   'Compania de Chocolate (Salgado)',
#   'Ocumare',
#   2008,
#   '70%',
#   'Argentina',
#   3.75,
#   'Criollo',
#   'Venezuela'),
#  (444,
#   'Compania de Chocolate (Salgado)',
#   'Esmeraldas',
#   2008,
#   '88%',
#   'Argentina',
#   2.75,
#   'Forastero (Nacional)',
#   'Ecuador'),
#  (445, 'Condor', 'Camino Verde', 2015, '76%', 'U.S.A.', 3.5, '', 'Ecuador'),
#  (446,
#   'Confluence',
#   'Tien Giang, 2015, batch 10-2-16',
#   2016,
#   '78%',
#   'U.S.A.',
#   2.75,
#   'Trinitario',
#   'Vietnam'),
#  (447,
#   'Coppeneur',
#   'Ecuador, Puristique',
#   2013,
#   '65%',
#   'Germany',
#   3.25,
#   'Forastero (Nacional)',
#   'Ecuador'),
#  (448,
#   'Coppeneur',
#   'Ghana Puristique',
#   2012,
#   '85%',
#   'Germany',
#   3.5,
#   'Forastero',
#   'Ghana'),
#  (449,
#   'Coppeneur',
#   'Ecuador Puristique',
#   2012,
#   '100%',
#   'Germany',
#   1.5,
#   '',
#   'Ecuador'),
#  (450,
#   'Coppeneur',
#   'Uba Budo',
#   2012,
#   '72%',
#   'Germany',
#   3.75,
#   'Forastero',
#   'Sao Tome & Principe'),
#  (451,
#   'Coppeneur',
#   'Madagascar',
#   2012,
#   '70%',
#   'Germany',
#   3.5,
#   'Trinitario',
#   'Madagascar'),
#  (452,
#   'Coppeneur',
#   'Grenada',
#   2010,
#   '72%',
#   'Germany',
#   3.25,
#   'Trinitario',
#   'Grenada'),
#  (453,
#   'Coppeneur',
#   'Chuao',
#   2010,
#   '70%',
#   'Germany',
#   3.0,
#   'Trinitario',
#   'Venezuela'),
#  (454,
#   'Coppeneur',
#   'Los Rios, H. Iara',
#   2010,
#   '72%',
#   'Germany',
#   2.5,
#   'Nacional',
#   'Ecuador'),
#  (455,
#   'Coppeneur',
#   'Trinidad',
#   2010,
#   '72%',
#   'Germany',
#   3.0,
#   'Trinitario',
#   'Trinidad'),
#  (456,
#   'Coppeneur',
#   'Jamaica',
#   2010,
#   '72%',
#   'Germany',
#   3.25,
#   'Trinitario',
#   'Jamaica'),
#  (457,
#   'Coppeneur',
#   'Ocumare 61',
#   2010,
#   '72%',
#   'Germany',
#   3.25,
#   'Criollo (Ocumare 61)',
#   'Venezuela'),
#  (458,
#   'Coppeneur',
#   'Porcelana, Apotequil',
#   2009,
#   '72%',
#   'Germany',
#   3.0,
#   'Criollo',
#   'Peru'),
#  (459,
#   'Coppeneur',
#   'Porcelana, Apotequil',
#   2009,
#   '62%',
#   'Germany',
#   3.25,
#   'Criollo',
#   'Peru'),
#  (460,
#   'Coppeneur',
#   'Chuao 100hr',
#   2009,
#   '70%',
#   'Germany',
#   3.5,
#   'Criollo, Trinitario',
#   'Venezuela'),
#  (461,
#   'Coppeneur',
#   'Chuao 70hr',
#   2009,
#   '70%',
#   'Germany',
#   3.75,
#   'Criollo, Trinitario',
#   'Venezuela'),
#  (462,
#   'Coppeneur',
#   'Porcelana, Tabasco, Mexico',
#   2008,
#   '72%',
#   'Germany',
#   3.0,
#   'Criollo',
# ...
#  (854,
#   'Hummingbird',
#   'Ocumare, Cumboto',
#   2013,
#   '70%',
#   'Canada',
#   3.25,
#   'Trinitario, Criollo',
#   'Venezuela'),
#  (855,
#   'Hummingbird',
#   'Amazonas',
#   2013,
#   '70%',
#   'Canada',
#   3.75,
#   'Forastero',
#   'Venezuela'),
#  (856,
#   'Idilio (Felchlin)',
#   'Chuao, Venezuela',
#   2013,
#   '72%',
#   'Switzerland',
#   3.75,
#   'Trinitario',
#   'Venezuela'),
#  (857,
#   'Idilio (Felchlin)',
#   'Coopertiva Amazona',
#   2011,
#   '72%',
#   'Switzerland',
#   3.75,
#   'Criollo',
#   'Venezuela'),
#  (858,
#   'Idilio (Felchlin)',
#   'Sur del Lago, Amiari Meridena, Zulia, 48hr c.',
#   2011,
#   '72%',
#   'Switzerland',
#   3.75,
#   '',
#   'Venezuela'),
#  (859,
#   'Idilio (Felchlin)',
#   'Choroni, Finca Torres, 48hr c.',
#   2011,
#   '72%',
#   'Switzerland',
#   3.25,
#   'Criollo',
#   'Venezuela'),
#  (860,
#   'Idilio (Felchlin)',
#   'Ocumare, H. Cata, 48hr c.',
#   2011,
#   '72%',
#   'Switzerland',
#   3.75,
#   'Criollo',
#   'Venezuela'),
#  (861,
#   'Idilio (Felchlin)',
#   'Porcelana, Zulia',
#   2011,
#   '74%',
#   'Switzerland',
#   4.0,
#   'Criollo',
#   'Venezuela'),
#  (862,
#   'Idilio (Felchlin)',
#   'Ocumare, H. Cata, w/ nibs',
#   2011,
#   '72%',
#   'Switzerland',
#   3.5,
#   'Criollo',
#   'Venezuela'),
#  (863,
#   'Idilio (Felchlin)',
#   'Carenero Superior, Urrutia, Barlovento',
#   2011,
#   '70%',
#   'Switzerland',
#   4.0,
#   'Trinitario',
#   'Venezuela'),
#  (864,
#   'Idilio (Felchlin)',
#   'Coopertiva Amazona w/ nibs',
#   2011,
#   '72%',
#   'Switzerland',
#   4.0,
#   'Criollo',
#   'Venezuela'),
#  (865,
#   'Idilio (Felchlin)',
#   'Sur del Lago, Amiari Meridena, Zulia, w/ nibs',
#   2011,
#   '72%',
#   'Switzerland',
#   4.0,
#   '',
#   'Venezuela'),
#  (866, 'Indah', 'India (south)', 2016, '61%', 'India', 2.5, '', 'India'),
#  (867,
#   'Indaphoria',
#   'La Red',
#   2012,
#   '70%',
#   'U.S.A.',
#   3.25,
#   '',
#   'Dominican Republic'),
#  (868,
#   'Indaphoria',
#   'Conacado, Manifesto',
#   2012,
#   '70%',
#   'U.S.A.',
#   2.75,
#   '',
#   'Dominican Republic'),
#  (869, 'Indi', 'Honduras', 2014, '77%', 'U.S.A.', 3.0, '', 'Honduras'),
#  (870,
#   'iQ Chocolate',
#   'Satipo region, white label',
#   2012,
#   '72%',
#   'Scotland',
#   2.75,
#   'Criollo',
#   'Peru'),
#  (871,
#   'iQ Chocolate',
#   'black label',
#   2012,
#   '72%',
#   'Scotland',
#   3.0,
#   '',
#   'Peru'),
#  (872,
#   'Isidro',
#   'Madagascar',
#   2014,
#   '72%',
#   'U.S.A.',
#   3.5,
#   'Trinitario',
#   'Madagascar'),
#  (873, 'Isidro', 'Peru', 2014, '72%', 'U.S.A.', 2.25, '', 'Peru'),
#  (874,
#   'Isidro',
#   'Belize',
#   2014,
#   '72%',
#   'U.S.A.',
#   3.25,
#   'Trinitario',
#   'Belize'),
#  (875,
#   'Isidro',
#   'Dominican Republic',
#   2014,
#   '72%',
#   'U.S.A.',
#   3.25,
#   '',
#   'Dominican Republic'),
#  (876,
#   'Izard',
#   'Maya Mountain, Toledo, Batch 29',
#   2015,
#   '70%',
#   'U.S.A.',
#   3.5,
#   'Trinitario',
#   'Belize'),
#  (877,
#   'Izard',
#   'Elvesia P., Batch 32',
#   2015,
#   '70%',
#   'U.S.A.',
#   2.75,
#   '',
#   'Dominican Republic'),
#  (878,
#   'Jacque Torres',
#   'Trinatario Treasure',
#   2006,
#   '71%',
#   'U.S.A.',
#   2.0,
#   'Trinitario',
#   'Ghana'),
#  (879,
#   'Jordis',
#   'Madagascar',
#   2015,
#   '63%',
#   'Czech Republic',
#   2.75,
#   'Trinitario',
#   'Madagascar'),
#  (880,
#   'Just Good Chocolate',
#   'Belize',
#   2014,
#   '70%',
#   'U.S.A.',
#   3.5,
#   'Trinitario',
#   'Belize'),
#  (881,
#   'Just Good Chocolate',
#   'Madagascar',
#   2014,
#   '70%',
#   'U.S.A.',
#   3.5,
#   'Trinitario',
#   'Madagascar'),
#  (882, 'Just Good Chocolate', 'Peru', 2014, '70%', 'U.S.A.', 4.0, '', 'Peru'),
#  (883,
#   'Kah Kow',
#   'Rizek Cacao, Cibao Valley, Domin. Rep.',
#   2013,
#   '70%',
#   'Domincan Republic',
#   3.5,
#   '',
#   'Dominican Republic'),
#  (884,
#   'Kah Kow',
#   'Rizek Cacao, Domin. Rep.',
#   2013,
#   '82%',
#   'Domincan Republic',
#   3.0,
#   '',
#   'Dominican Republic'),
#  (885,
#   'Kah Kow',
#   'Rizek Cacao, Domin. Rep.',
#   2013,
#   '55%',
#   'Domincan Republic',
#   3.25,
#   '',
#   'Dominican Republic'),
#  (886,
#   'Kah Kow',
#   'Rizek Cacao, Domin. Rep.',
#   2013,
#   '62%',
#   'Domincan Republic',
#   3.25,
#   '',
#   'Dominican Republic'),
#  (887, 'Kakao', 'Peru', 2012, '64%', 'Germany', 2.5, '', 'Peru'),
#  (888,
#   'Kakao',
#   'Vanuatu',
#   2009,
#   '65%',
#   'Germany',
#   3.75,
#   'Trinitario',
#   'Vanuatu'),
#  (889,
#   'Kallari (Ecuatoriana)',
#   'Sisa 36hr/ W. F. blend prototype',
#   2008,
#   '70%',
#   'Ecuador',
#   3.0,
#   '',
#   'Ecuador'),
#  (890,
#   'Kallari (Ecuatoriana)',
#   "Sisa's Secret/ original micro",
#   2008,
#   '70%',
#   'Ecuador',
#   3.5,
#   '',
#   'Ecuador'),
#  (891,
#   'Kallari (Ecuatoriana)',
#   'Roberto',
#   2008,
#   '75%',
#   'Ecuador',
#   2.75,
#   '',
#   'Ecuador'),
#  (892,
#   'Kallari (Ecuatoriana)',
#   'Diego/ original micro',
#   2008,
#   '85%',
#   'Ecuador',
#   2.5,
#   '',
#   'Ecuador'),
#  (893,
#   'Kallari (Ecuatoriana)',
#   'Diego 48hr/ W.F. blend prototype',
#   2008,
#   '85%',
#   'Ecuador',
#   2.75,
#   '',
#   'Ecuador'),
#  (894,
#   'Kallari (Ecuatoriana)',
#   'Diego 60hr/ W.F. blend prototype',
#   2008,
#   '85%',
#   'Ecuador',
#   3.0,
#   '',
#   'Ecuador'),
#  (895,
#   'Kallari (Ecuatoriana)',
#   'Cacao Nacional W.F.',
#   2008,
#   '75%',
#   'Ecuador',
#   2.5,
#   '',
#   'Ecuador'),
#  (896,
#   'Kallari (Ecuatoriana)',
#   'Cacao Nacional W.F.',
#   2008,
#   '85%',
#   'Ecuador',
#   3.0,
#   '',
#   'Ecuador'),
#  (897, 'Kaoka (Cemoi)', 'Noir', 2009, '70%', 'France', 2.75, '', ''),
#  (898, 'Kaoka (Cemoi)', 'Ecuador', 2009, '80%', 'France', 2.75, '', 'Ecuador'),
#  (899,
#   'Kerchner',
#   'La Red, Project Reserva, Guaconejo',
#   2013,
#   '70%',
#   'U.S.A.',
#   3.75,
#   '',
#   'Dominican Republic'),
#  (900, "Ki' Xocolatl", 'Dark', 2009, '72%', 'Mexico', 2.0, '', 'Mexico'),
#  (901,
#   'Kiskadee',
#   'La Red, Guanconjeco',
#   2014,
#   '60%',
#   'U.S.A.',
#   3.0,
#   'Trinitario',
#   'Dominican Republic'),
#  (902, 'Kto', 'San Martin', 2014, '72%', 'U.S.A.', 2.5, '', 'Peru'),
#  (903, 'Kto', 'Ocumare', 2014, '72%', 'U.S.A.', 2.75, '', 'Venezuela'),
#  (904, 'Kto', 'Belize', 2014, '72%', 'U.S.A.', 3.0, 'Trinitario', 'Belize'),
#  (905,
#   'Kto',
#   'Sambirano Valley',
#   2014,
#   '72%',
#   'U.S.A.',
#   3.25,
#   'Trinitario',
#   'Madagascar'),
#  (906, 'Kto', 'Belize', 2014, '90%', 'U.S.A.', 3.25, 'Trinitario', 'Belize'),
#  (907,
#   'Kto',
#   'Elvesia',
#   2014,
#   '72%',
#   'U.S.A.',
#   3.25,
#   '',
#   'Dominican Republic'),
#  (908, 'Kto', 'ROIG', 2014, '72%', 'U.S.A.', 3.25, '', 'Dominican Republic'),
#  (909,
#   "K'ul",
#   'Kafupbo, Petit Bourg, De Borgnes',
#   2016,
#   '70%',
#   'U.S.A.',
#   3.25,
#   '',
#   'Haiti'),
#  (910,
#   "K'ul",
#   'Maranon, Fortunato No. 4',
#   2016,
#   '70%',
#   'U.S.A.',
#   2.75,
#   'Forastero (Nacional)',
#   'Peru'),
#  (911,
#   "K'ul",
#   'Los Rios, Hacienda Limon, Heirloom',
#   2016,
#   '70%',
#   'U.S.A.',
#   3.75,
#   '',
#   'Ecuador'),
#  (912,
#   "K'ul",
#   'Bahia, Fazenda Camboa',
#   2016,
#   '70%',
#   'U.S.A.',
#   3.75,
#   'Forastero',
#   'Brazil'),
#  (913, 'Kyya', 'Uganda', 2014, '72.50%', 'U.S.A.', 2.5, 'Forastero', 'Uganda'),
#  (914,
#   'Kyya',
#   'Hispaniola',
#   2014,
#   '72.50%',
#   'U.S.A.',
#   3.0,
#   '',
#   'Dominican Republic'),
#  (915, 'Kyya', 'Ecuador', 2014, '72.50%', 'U.S.A.', 2.5, '', 'Ecuador'),
#  (916,
#   'Kyya',
#   'Madagascar',
#   2014,
#   '72.50%',
#   'U.S.A.',
#   3.0,
#   'Trinitario',
#   'Madagascar'),
#  (917,
#   'L.A. Burdick (Felchlin)',
#   'Peru',
#   2012,
#   '74%',
#   'U.S.A.',
#   3.25,
#   '',
#   'Peru'),
#  (918,
#   'L.A. Burdick (Felchlin)',
#   'Brazil',
#   2012,
#   '70%',
#   'U.S.A.',
#   4.0,
#   '',
#   'Brazil'),
#  (919,
#   'L.A. Burdick (Felchlin)',
#   'Chuao',
#   2012,
#   '68%',
#   'U.S.A.',
#   3.75,
#   'Trinitario',
#   'Venezuela'),
#  (920,
#   'L.A. Burdick (Felchlin)',
#   'Quito',
#   2011,
#   '74%',
#   'U.S.A.',
#   3.75,
#   '',
#   'Ecuador'),
#  (921,
#   'L.A. Burdick (Felchlin)',
#   'Grenada',
#   2010,
#   '75%',
#   'U.S.A.',
#   3.25,
#   'Trinitario',
#   'Grenada'),
#  (922,
#   'L.A. Burdick (Felchlin)',
#   'Dominican Republic',
#   2010,
#   '74%',
#   'U.S.A.',
#   3.75,
#   '',
#   'Dominican Republic'),
#  (923,
#   'L.A. Burdick (Felchlin)',
#   'Venzuela',
#   2010,
#   '71%',
#   'U.S.A.',
#   3.0,
#   '',
#   'Venezuela'),
#  (924,
#   'L.A. Burdick (Felchlin)',
#   'Madagascar',
#   2009,
#   '64%',
#   'U.S.A.',
#   3.5,
#   'Trinitario',
#   'Madagascar'),
#  (925,
#   'L.A. Burdick (Felchlin)',
#   'Bolivian',
#   2009,
#   '68%',
#   'U.S.A.',
#   3.0,
#   '',
#   'Bolivia'),
#  (926,
#   'La Chocolaterie Nanairo',
#   'Lumas, 2015 Harvest, Batch 6, brown sugar',
#   2016,
#   '70%',
#   'Japan',
#   2.25,
#   'Trinitario, Criollo',
#   'Peru'),
#  (927,
#   'La Chocolaterie Nanairo',
#   'Lumas, 2015 Harvest, Batch 7',
#   2016,
#   '70%',
#   'Japan',
#   2.5,
#   'Trinitario, Criollo',
#   'Peru'),
#  (928,
#   'La Chocolaterie Nanairo',
#   'Tumbes, 2013 Harvest, Batch 8',
#   2016,
#   '70%',
#   'Japan',
#   3.0,
#   'Criollo',
#   'Peru'),
#  (929,
#   'La Chocolaterie Nanairo',
#   'Belize, 2014 Harvest, Batch 9',
#   2016,
#   '70%',
#   'Japan',
#   3.0,
#   'Trinitario, Criollo',
#   'Belize'),
#  (930,
#   'La Maison du Chocolat (Valrhona)',
#   'Cuana, 2013',
#   2013,
#   '74%',
#   'France',
#   2.75,
#   '',
#   'Africa, Carribean, C. Am.'),
#  (931,
#   'La Maison du Chocolat (Valrhona)',
#   'Tobago',
#   2013,
#   '60%',
#   'France',
#   3.25,
#   '',
#   'Tobago'),
#  (932,
#   'La Maison du Chocolat (Valrhona)',
#   'Acarigua, w/ nibs',
#   2013,
#   '56%',
#   'France',
#   3.25,
#   '',
#   'Ecuador'),
#  (933,
#   'La Maison du Chocolat (Valrhona)',
#   'Loma Sotavento',
#   2012,
#   '66%',
#   'France',
#   3.5,
#   '',
#   'Dominican Republic'),
#  (934,
#   'La Maison du Chocolat (Valrhona)',
#   'Grenada',
#   2011,
#   '68%',
#   'France',
#   3.5,
#   'Trinitario',
#   'Grenada'),
#  (935,
#   'La Maison du Chocolat (Valrhona)',
#   'Akosombo',
#   2009,
#   '68%',
#   'France',
#   3.25,
#   'Forastero',
#   'Ghana'),
#  (936,
#   'La Maison du Chocolat (Valrhona)',
#   'Porcelana, Pariguan',
#   2009,
#   '69%',
#   'France',
#   3.5,
#   'Criollo (Porcelana)',
#   'Venezuela'),
#  (937,
#   'La Maison du Chocolat (Valrhona)',
#   'Kuruba',
#   2009,
#   '60%',
#   'France',
#   3.0,
#   '',
#   ''),
#  (938,
#   'La Maison du Chocolat (Valrhona)',
#   'Orinoco',
#   2009,
#   '60%',
#   'France',
#   3.75,
#   '',
#   ''),
#  (939,
#   'La Maison du Chocolat (Valrhona)',
#   'Cuana, 2008',
#   2008,
#   '74%',
#   'France',
#   3.5,
#   'Blend',
#   'Ven., Indonesia, Ecuad.'),
#  (940,
#   'La Oroquidea',
#   'Peruvian Amazon',
#   2011,
#   '72%',
#   'Peru',
#   2.5,
#   '',
#   'Peru'),
#  (941,
#   'La Pepa de Oro',
#   'Vinces',
#   2011,
#   '60%',
#   'Ecuador',
#   3.25,
#   '',
#   'Ecuador'),
#  (942,
#   'Laia aka Chat-Noir',
#   'Madagascar, Batch 59/100',
#   2015,
#   '75%',
#   'France',
#   2.75,
#   'Trinitario',
#   'Madagascar'),
#  (943,
#   'Laia aka Chat-Noir',
#   'Vietnam, Batch 50/100',
#   2015,
#   '75%',
#   'France',
#   2.75,
#   'Trinitario',
#   'Vietnam'),
#  (944,
#   'Laia aka Chat-Noir',
#   'Cuba, Batch 59/100',
#   2015,
#   '75%',
#   'France',
#   3.0,
#   '',
#   'Cuba'),
#  (945,
#   'Laia aka Chat-Noir',
#   'Peru, Batch 51/100',
#   2015,
#   '75%',
#   'France',
#   3.25,
#   '',
#   'Peru'),
#  (946,
#   'Laia aka Chat-Noir',
#   'Ivory Coast, Batch 56/100',
#   2015,
#   '75%',
#   'France',
#   3.0,
#   '',
#   'Ivory Coast'),
#  (947,
#   'Laia aka Chat-Noir',
#   'Sao Tome, Batch 151',
#   2015,
#   '75%',
#   'France',
#   3.5,
#   'Forastero',
#   'Sao Tome'),
#  (948,
#   'Laia aka Chat-Noir',
#   'Bahia, Batch 148',
#   2015,
#   '75%',
#   'France',
#   3.25,
#   '',
#   'Brazil'),
#  (949,
#   'Laia aka Chat-Noir',
#   'Lam Dong, Batch 153',
#   2015,
#   '75%',
#   'France',
#   3.75,
#   'Trinitario',
#   'Vietnam'),
#  (950, 'Laia aka Chat-Noir', 'Cuba', 2014, '70%', 'France', 2.75, '', 'Cuba'),
#  (951,
#   'Laia aka Chat-Noir',
#   'Trinidad-Tobago',
#   2014,
#   '68%',
#   'France',
#   2.75,
#   '',
#   'Trinidad-Tobago'),
#  (952,
#   'Lajedo do Ouro',
#   'Catongo',
#   2012,
#   '70%',
#   'Brazil',
#   3.5,
#   'Forastero (Catongo)',
#   'Brazil'),
#  (953,
#   'Lake Champlain (Callebaut)',
#   'Tanzania',
#   2009,
#   '75%',
#   'U.S.A.',
#   2.5,
#   '',
#   'Tanzania'),
#  (954,
#   "L'Amourette",
#   'Rugoso',
#   2016,
#   '80%',
#   'U.S.A.',
#   3.5,
#   'Trinitario',
#   'Nicaragua'),
#  (955,
#   "L'Amourette",
#   'Carenero Superior',
#   2012,
#   '75%',
#   'U.S.A.',
#   3.0,
#   'Trinitario',
#   'Venezuela'),
#  (956,
#   "L'Amourette",
#   'Rio Caribe',
#   2012,
#   '75%',
#   'U.S.A.',
#   3.0,
#   'Trinitario',
#   'Venezuela'),
#  (957,
#   "L'Amourette",
#   'Blend',
#   2012,
#   '72%',
#   'U.S.A.',
#   3.0,
#   'Criollo',
#   'Peru, Ecuador, Venezuela'),
#  (958,
#   'Letterpress',
#   'La Masica, Batch 7, FHIA',
#   2017,
#   '70%',
#   'U.S.A.',
#   3.5,
#   '',
#   'Honduras'),
#  (959,
#   'Letterpress',
#   'Maya Mtn, Batch 18, Heirloom',
#   2017,
#   '70%',
#   'U.S.A.',
#   3.25,
#   '',
#   'Belize'),
#  (960, 'Letterpress', 'Liberia', 2016, '70%', 'U.S.A.', 3.25, '', 'Liberia'),
#  (961, 'Letterpress', 'Beniamo', 2015, '70%', 'U.S.A.', 3.25, '', 'Bolivia'),
#  (962,
#   'Letterpress',
#   'San Juan Estate, Gran Couva',
#   2015,
#   '70%',
#   'U.S.A.',
#   3.5,
#   'Trinitario',
#   'Trinidad'),
#  (963,
#   'Letterpress',
#   'San Andres',
#   2015,
#   '70%',
#   'U.S.A.',
#   3.0,
#   '',
#   'Costa Rica'),
#  (964,
#   'Letterpress',
#   'La Red, Guaconejo',
#   2015,
#   '70%',
#   'U.S.A.',
#   3.25,
#   '',
#   'Domincan Republic'),
#  (965,
#   'Letterpress',
#   'Kokoa Kamili',
#   2015,
#   '70%',
#   'U.S.A.',
#   3.5,
#   '',
#   'Tanzania'),
#  (966,
#   'Letterpress',
#   'Maranura',
#   2014,
#   '70%',
#   'U.S.A.',
#   3.5,
#   'Forastero (Nacional)',
#   'Peru'),
#  (967,
#   'Levy',
#   'Sambirano',
#   2014,
#   '71%',
#   'Finland',
#   3.5,
#   'Criollo',
#   'Madagascar'),
#  (968,
#   'Lilla',
#   'Madagascar',
#   2016,
#   '70%',
#   'Finland',
#   3.0,
#   'Trinitario',
#   'Madagascar'),
#  (969,
#   'Lillie Belle',
#   'Perfect Illusion',
#   2012,
#   '65%',
#   'U.S.A.',
#   3.5,
#   'Criollo',
#   'Peru'),
#  (970,
#   'Lillie Belle',
#   'Bolivia, Wild Thing',
#   2012,
#   '68%',
#   'U.S.A.',
#   3.5,
#   'Criollo',
#   'Bolivia'),
#  (971, 'Lillie Belle', 'La Selva', 2012, '68%', 'U.S.A.', 3.75, '', 'Peru'),
#  (972,
#   'Lillie Belle',
#   'Purple Haze',
#   2012,
#   '75%',
#   'U.S.A.',
#   2.75,
#   '',
#   'Venezuela, Dom. Rep.'),
#  (973,
#   'Lillie Belle',
#   'The Other One, Grand Cru',
#   2012,
#   '74%',
#   'U.S.A.',
#   3.0,
#   '',
#   'Dominican Republic'),
#  (974,
#   'Lillie Belle',
#   'Wild Thing',
#   2012,
#   '68%',
#   'U.S.A.',
#   3.5,
#   'Criollo',
#   'Bolivia'),
#  (975,
#   'Lindt & Sprungli',
#   'Excellence (US Version)',
#   2007,
#   '85%',
#   'Switzerland',
#   3.0,
#   '',
#   ''),
#  (976,
#   'Loiza',
#   'Puerto Rico',
#   2013,
#   '65%',
#   'Puerto Rico',
#   2.5,
#   '',
#   'Puerto Rico'),
#  (977,
#   'Lonohana',
#   "Haleiwa, O'ahu; Lonohana E., Kanahiku",
#   2014,
#   '70%',
#   'U.S.A.',
#   3.75,
#   '',
#   'Hawaii'),
#  (978,
#   'Lonohana',
#   "Haleiwa E, O'ahu, 2014",
#   2014,
#   '65%',
#   'U.S.A.',
#   3.25,
#   '',
#   'Hawaii'),
#  (979,
#   'Lonohana',
#   "Haleiwa E, O'ahu, 2014",
#   2014,
#   '75%',
#   'U.S.A.',
#   3.75,
#   '',
#   'Hawaii'),
#  (980,
#   'Lonohana',
#   "Opaeula Estate, O'ahu, Nene, CG Exclusive",
#   2013,
#   '71%',
#   'U.S.A.',
#   3.0,
#   '',
#   'Hawaii'),
#  (981,
#   'Lonohana',
#   "Opaeula Estate, O'ahu, Ele'ele",
#   2013,
#   '72%',
#   'U.S.A.',
#   3.0,
#   '',
#   'Hawaii'),
#  (982,
#   'Lonohana',
#   'Hawaiian Crown, Kona Vanilla',
#   2013,
#   '70%',
#   'U.S.A.',
#   3.5,
#   '',
#   'Hawaii'),
#  (983, 'Love Bar', 'Nicaragua', 2015, '75%', 'U.S.A.', 2.0, '', 'Nicaragua'),
#  (984,
#   'Luker',
#   'Selva',
#   2010,
#   '46%',
#   'Colombia',
#   2.75,
#   '',
#   'Colombia, Ecuador'),
#  (985,
#   'Luker',
#   'Macondo',
#   2010,
#   '60%',
#   'Colombia',
#   3.0,
#   '',
#   'Colombia, Ecuador'),
#  (986,
#   'Luker',
#   'Misterio',
#   2010,
#   '58%',
#   'Colombia',
#   3.0,
#   '',
#   'Colombia, Ecuador'),
#  (987, 'Luker', 'Santander', 2010, '65%', 'Colombia', 3.5, '', 'Colombia'),
#  (988,
#   'Machu Picchu Trading Co.',
#   'Peru',
#   2011,
#   '70%',
#   'Peru',
#   1.5,
#   '',
#   'Peru'),
#  (989,
#   'Machu Picchu Trading Co.',
#   'Peru',
#   2010,
#   '55%',
#   'Peru',
#   2.25,
#   '',
#   'Peru'),
#  (990,
#   'Madecasse (Cinagra)',
#   'Madagascar',
#   2008,
#   '67%',
#   'Madagascar',
#   3.5,
#   'Trinitario',
#   'Madagascar'),
#  (991,
#   'Madecasse (Cinagra)',
#   'Madagascar',
#   2008,
#   '70%',
#   'Madagascar',
#   3.75,
#   'Trinitario',
#   'Madagascar'),
#  (992,
#   'Madecasse (Cinagra)',
#   'Madagascar',
#   2008,
#   '63%',
#   'Madagascar',
#   4.0,
#   'Trinitario',
#   'Madagascar'),
#  (993,
#   'Madecasse (Cinagra)',
#   'Madagascar',
#   2008,
#   '75%',
#   'Madagascar',
#   3.5,
#   'Trinitario',
#   'Madagascar'),
#  (994,
#   'Madre',
#   'Guadalcanal',
#   2017,
#   '73%',
#   'U.S.A.',
#   3.5,
#   '',
#   'Solomon Islands'),
#  (995, 'Madre', 'Puerto Rico', 2013, '70%', 'U.S.A.', 2.75, '', 'Puerto Rico'),
#  (996, 'Madre', 'Brazil', 2013, '70%', 'U.S.A.', 3.5, '', 'Brazil'),
#  (997, 'Madre', 'Choobua, Kona', 2013, '70%', 'U.S.A.', 2.75, '', 'Hawaii'),
#  (998,
#   'Madre',
#   'Xocunusco, Chiapas, Pichucalco',
#   2013,
#   '70%',
#   'U.S.A.',
#   2.75,
#   '',
#   'Mexico'),
#  (999,
#   'Madre',
#   'Hamakua Coast, Kokoleka',
#   2012,
#   '70%',
#   'U.S.A.',
#   3.25,
#   '',
#   'Hawaii'),
#  ...]

# %%
# create engine to connect to the ETL_Project DB
engine = create_engine('postgres://postgres:blU89bRd*@localhost:5432/cacao_db')
conn = engine.connect()

# add the cacao bean dataframe into the cacao table in postgres
cacaobean_dropna_df.to_sql('cacao_db', con = engine, if_exists = 'append', chunksize = 1000)

# return the cacao bean table
cacao = pd.read_sql("SELECT * FROM cacao_db", conn)
cacao.head()
